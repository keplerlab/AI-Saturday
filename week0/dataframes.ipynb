# %% [markdown]
# # Dataframes Kung-fu with Pandas
#
# <img style="float: right;" src="data/po.png" width=256>
# **TL;DR**
# - Read CSVs into dataframes
# - Explore dataframe and show statistics
# - Indexing and slicing
# - Find and replace

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading a CSV into dataframe
df = pd.read_csv('data/Major-AI-projects.csv')

# Show column names and number of rows
cols = df.columns.values.tolist()
rows = df.index
print('cols:\n{}\n'.format(', '.join(cols)))
print('num_rows:\n{}\n'.format(len(rows)))
# Out:
# cols:
# Project, Type, Category, Insitution / Company, Developer / Author / Group Lead, Location, Year, Description, Written in, Image, Wikipedia Page, Homepage or Source Code
#
# num_rows:
# 54

# %%
# First five items of the dataframe.
df.head()
# Out:
#          Project                                         Type  \
# 0      Deep Blue                         Specialized Projects
# 1   Stockfish AI                         Specialized Projects
# 2     Google Now                         Specialized Projects
# 3        OpenCog  Specialized Projects, Multipurpose Projects
# 4  Apache Mahout                        Multipurpose Projects
#
#                                      Category  \
# 0                                       Games
# 1                                       Games
# 2                     Knowledge and Reasoning
# 3  Cognitive Architechture, Software Packages
# 4                           Software Packages
#
#               Insitution / Company  \
# 0  IBM, Carnegie Mellon University
# 1                              NaN
# 2                           Google
# 3               OpenCog Foundation
# 4       Apache Software Foundation
#
#                      Developer / Author / Group Lead       Location  Year  \
# 0  Feng-hsiung Hsu, Thomas Anantharaman, Murray C...  United States  1985
# 1         Tord Romstad, Marco Costalba, Joona Kiiski  Norway, Italy  2004
# 2                                                NaN  United States  2012
# 3                                       Ben Goertzel  United States  2008
# 4        Isabel Drost, Grant Ingersoll, Karl Wettin.  United States  2010
#
#                                          Description             Written in  \
# 0  Deep Blue was a chess-playing computer develop...                  C/C++
# 1  Stockfish is a strong open source UCI chess en...                  C/C++
# 2  Google Now is an intelligent personal assistan...                  C/C++
# 3  OpenCog is a project that aims to build an ope...  C/C++, Python, Scheme
# 4  Apache Mahout is a project of the Apache Softw...                   Java
#
#                                                Image  \
# 0  http://upload.wikimedia.org/wikipedia/commons/...
# 1  http://upload.wikimedia.org/wikipedia/en/thumb...
# 2  http://upload.wikimedia.org/wikipedia/en/thumb...
# 3  http://upload.wikimedia.org/wikipedia/en/thumb...
# 4                                                NaN
#
#                                       Wikipedia Page  \
# 0  http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# 1     http://en.wikipedia.org/wiki/Stockfish_(chess)
# 2            http://en.wikipedia.org/wiki/Google_Now
# 3               http://en.wikipedia.org/wiki/OpenCog
# 4         http://en.wikipedia.org/wiki/Apache_Mahout
#
#                              Homepage or Source Code
# 0  http://www-03.ibm.com/ibm/history/ibm100/us/en...
# 1                     http://www.stockfishchess.org/
# 2                     http://google.com/landing/now/
# 3                                http://opencog.org/
# 4                          http://mahout.apache.org/

# %%
# Use pandas.DataFrames.describe() to generate a descriptive statistics.
df.describe()
# Out:
#            Project                  Type                 Category  \
# count           54                    54                       54
# unique          54                     3                       11
# top     RapidMiner  Specialized Projects  Cognitive Architechture
# freq             1                    45                       15
#
#        Insitution / Company Developer / Author / Group Lead       Location  \
# count                    47                              38             53
# unique                   38                              36             13
# top                     MIT                 Rollo Carpenter  United States
# freq                      4                               2             40
#
#         Year                                        Description Written in  \
# count     40                                                 54         25
# unique    27                                                 54         13
# top     2005  Encog is a machine learning framework availabl...       LISP
# freq       3                                                  1          7
#
#                                                     Image  \
# count                                                  16
# unique                                                 16
# top     http://upload.wikimedia.org/wikipedia/commons/...
# freq                                                    1
#
#                                            Wikipedia Page  \
# count                                                  53
# unique                                                 53
# top     http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# freq                                                    1
#
#                                   Homepage or Source Code
# count                                                  45
# unique                                                 45
# top     http://groups.csail.mit.edu/lbr/humanoid-robot...
# freq                                                    1

# %%
# Data shows the major AI projects done by different organizations.
# Let's find out the frequency of projects done for each category.
plt.figure(figsize=(20, 5))
plt.xticks(rotation=45)
df.Category.hist()
plt.title('Frequency of projects per category')
plt.show()

# %% [markdown]
# ## Indexing like a Ninja
#
# Guidelines:
# - use `.loc` for labels
# - use `.iloc` for positions
# - explicitly designate both rows and columns

# %%
""" Select a column by name """
# We add `:` to say that we are interested in all the rows.
# We add the column name to indicate the column we are interested in.
df.loc[:, 'Project'].head(10)
# Out:
# 0        Deep Blue
# 1     Stockfish AI
# 2       Google Now
# 3          OpenCog
# 4    Apache Mahout
# 5           CoJACK
# 6          Neuroph
# 7       RapidMiner
# 8             Weka
# 9            Encog
# Name: Project, dtype: object

# %%
# Note that the previous method returns the row as a Series.
# If we are only interested in the values we can do the following which will return a numpy array.
df.loc[:, 'Project'].values
# Out:
# array(['Deep Blue', 'Stockfish AI', 'Google Now', 'OpenCog',
#        'Apache Mahout', 'CoJACK', 'Neuroph', 'RapidMiner', 'Weka', 'Encog',
#        'Watson', 'Deeplearning4j', 'PARRY', '4CAPS', 'ACT-R', 'Copycat',
#        'Mycin', 'SNePS', 'Soar', 'Cyc', 'SHRDLU', 'Eurisko',
#        'Artificial Linguistic Internet Computer Entity', 'ELIZA',
#        'Wolfram Alpha', 'Chinook', 'Blue Brain Project', 'AIBO', 'Braina',
#        'CALO', 'CHREST', 'Cleverbot', 'Cog', 'CLARION', 'DUAL', 'EPIC',
#        'FORR', 'FreeHAL', 'Google Brain', 'Grok',
#        'Procedural Reasoning System', 'Microsoft Cortana', 'Jabberwacky',
#        'Open Mind Common Sense', 'P.A.N.', 'PreAct',
#        'Synthetic Environment for Analysis and Simulations', 'R-CAST',
#        'Siri', 'SYSTRAN', 'TD-Gammon', 'InfoTame', 'IDA and LIDA', 'NuPIC'], dtype=object)

# %%
# Till now we were using row numbers as index.
# We can specify a column to serve as index for our dataframe.
df.set_index('Project', inplace=True)

# %%
# Now if we want to select a particular value from the dataframe, say, which year the `Google Now` project was taken.
# We can do that easily.
df.loc['Google Now', 'Year']
# Out:
# '2012'

# %%
# Select several rows by labels - pass a list of labels in the row position.
df.loc[['Google Now', 'Deep Blue', 'Stockfish AI'], 'Year']
# Out:
# Project
# Google Now      2012
# Deep Blue       1985
# Stockfish AI    2004
# Name: Year, dtype: object

# %%
# We can also do the same for columns.
df.loc[['Google Now', 'Deep Blue', 'Stockfish AI'], ['Year', 'Written in']]
# Out:
#               Year Written in
# Project
# Google Now    2012      C/C++
# Deep Blue     1985      C/C++
# Stockfish AI  2004      C/C++

# %%
# Select several consecutive columns by label.
df.loc[:, 'Category': 'Written in'].head()
# Out:
#                                                  Category  \
# Project
# Deep Blue                                           Games
# Stockfish AI                                        Games
# Google Now                        Knowledge and Reasoning
# OpenCog        Cognitive Architechture, Software Packages
# Apache Mahout                           Software Packages
#
#                           Insitution / Company  \
# Project
# Deep Blue      IBM, Carnegie Mellon University
# Stockfish AI                               NaN
# Google Now                              Google
# OpenCog                     OpenCog Foundation
# Apache Mahout       Apache Software Foundation
#
#                                  Developer / Author / Group Lead  \
# Project
# Deep Blue      Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI          Tord Romstad, Marco Costalba, Joona Kiiski
# Google Now                                                   NaN
# OpenCog                                             Ben Goertzel
# Apache Mahout        Isabel Drost, Grant Ingersoll, Karl Wettin.
#
#                     Location  Year  \
# Project
# Deep Blue      United States  1985
# Stockfish AI   Norway, Italy  2004
# Google Now     United States  2012
# OpenCog        United States  2008
# Apache Mahout  United States  2010
#
#                                                      Description  \
# Project
# Deep Blue      Deep Blue was a chess-playing computer develop...
# Stockfish AI   Stockfish is a strong open source UCI chess en...
# Google Now     Google Now is an intelligent personal assistan...
# OpenCog        OpenCog is a project that aims to build an ope...
# Apache Mahout  Apache Mahout is a project of the Apache Softw...
#
#                           Written in
# Project
# Deep Blue                      C/C++
# Stockfish AI                   C/C++
# Google Now                     C/C++
# OpenCog        C/C++, Python, Scheme
# Apache Mahout                   Java

# %%
# Select rows based on column value.
# Select all the projects that were taken in the year 2004.
df.loc[df.loc[:, 'Year'] == '2004', :]
# Out:
#                                                                     Type  \
# Project
# Stockfish AI                                        Specialized Projects
# Synthetic Environment for Analysis and Simulations  Specialized Projects
#
#                                                    Category  \
# Project
# Stockfish AI                                          Games
# Synthetic Environment for Analysis and Simulations    Other
#
#                                                    Insitution / Company  \
# Project
# Stockfish AI                                                        NaN
# Synthetic Environment for Analysis and Simulations    Purdue University
#
#                                                                Developer / Author / Group Lead  \
# Project
# Stockfish AI                                        Tord Romstad, Marco Costalba, Joona Kiiski
# Synthetic Environment for Analysis and Simulations                          Alok R. Chaturvedi
#
#                                                          Location  Year  \
# Project
# Stockfish AI                                        Norway, Italy  2004
# Synthetic Environment for Analysis and Simulations  United States  2004
#
#                                                                                           Description  \
# Project
# Stockfish AI                                        Stockfish is a strong open source UCI chess en...
# Synthetic Environment for Analysis and Simulations  Purdue University's Synthetic Environment for ...
#
#                                                    Written in  \
# Project
# Stockfish AI                                            C/C++
# Synthetic Environment for Analysis and Simulations        NaN
#
#                                                                                                 Image  \
# Project
# Stockfish AI                                        http://upload.wikimedia.org/wikipedia/en/thumb...
# Synthetic Environment for Analysis and Simulations                                                NaN
#
#                                                                                        Wikipedia Page  \
# Project
# Stockfish AI                                           http://en.wikipedia.org/wiki/Stockfish_(chess)
# Synthetic Environment for Analysis and Simulations  http://en.wikipedia.org/wiki/Synthetic_Environ...
#
#                                                                               Homepage or Source Code
# Project
# Stockfish AI                                                           http://www.stockfishchess.org/
# Synthetic Environment for Analysis and Simulations  http://www.krannert.purdue.edu/centers/perc/ht...

# %%
# Select a row by position.
df.iloc[0, :]
# Out:
# Type                                                            Specialized Projects
# Category                                                                       Games
# Insitution / Company                                 IBM, Carnegie Mellon University
# Developer / Author / Group Lead    Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Location                                                               United States
# Year                                                                            1985
# Description                        Deep Blue was a chess-playing computer develop...
# Written in                                                                     C/C++
# Image                              http://upload.wikimedia.org/wikipedia/commons/...
# Wikipedia Page                     http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Homepage or Source Code            http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Name: Deep Blue, dtype: object

# %%
# Select a column by position
# Note that we are using the 'Project' column as index. So, column `Type' becomes the 0th column.
df.iloc[:, 0]
# Out:
# Project
# Deep Blue                                                                    Specialized Projects
# Stockfish AI                                                                 Specialized Projects
# Google Now                                                                   Specialized Projects
# OpenCog                                               Specialized Projects, Multipurpose Projects
# Apache Mahout                                                               Multipurpose Projects
# CoJACK                                                                       Specialized Projects
# Neuroph                                                                     Multipurpose Projects
# RapidMiner                                                                  Multipurpose Projects
# Weka                                                                        Multipurpose Projects
# Encog                                                                       Multipurpose Projects
# Watson                                                Specialized Projects, Multipurpose Projects
# Deeplearning4j                                                              Multipurpose Projects
# PARRY                                                                        Specialized Projects
# 4CAPS                                                                        Specialized Projects
# ACT-R                                                                        Specialized Projects
# Copycat                                                                      Specialized Projects
# Mycin                                                                        Specialized Projects
# SNePS                                                                        Specialized Projects
# Soar                                                                         Specialized Projects
# Cyc                                                                          Specialized Projects
# SHRDLU                                                                       Specialized Projects
# Eurisko                                                                      Specialized Projects
# Artificial Linguistic Internet Computer Entity                               Specialized Projects
# ELIZA                                                                        Specialized Projects
# Wolfram Alpha                                                                Specialized Projects
# Chinook                                                                      Specialized Projects
# Blue Brain Project                                                           Specialized Projects
# AIBO                                                                         Specialized Projects
# Braina                                                                       Specialized Projects
# CALO                                                                         Specialized Projects
# CHREST                                                                       Specialized Projects
# Cleverbot                                                                    Specialized Projects
# Cog                                                                          Specialized Projects
# CLARION                                                                      Specialized Projects
# DUAL                                                                         Specialized Projects
# EPIC                                                                         Specialized Projects
# FORR                                                                         Specialized Projects
# FreeHAL                                                                      Specialized Projects
# Google Brain                                                                 Specialized Projects
# Grok                                                                        Multipurpose Projects
# Procedural Reasoning System                                                  Specialized Projects
# Microsoft Cortana                                                            Specialized Projects
# Jabberwacky                                                                  Specialized Projects
# Open Mind Common Sense                                                       Specialized Projects
# P.A.N.                                                                       Specialized Projects
# PreAct                                                                       Specialized Projects
# Synthetic Environment for Analysis and Simulations                           Specialized Projects
# R-CAST                                                                       Specialized Projects
# Siri                                                                         Specialized Projects
# SYSTRAN                                                                      Specialized Projects
# TD-Gammon                                                                    Specialized Projects
# InfoTame                                                                     Specialized Projects
# IDA and LIDA                                                                 Specialized Projects
# NuPIC                                                                        Specialized Projects
# Name: Type, dtype: object

# %%
# Pick up a single value
df.iloc[0, 2]
# Out:
# 'IBM, Carnegie Mellon University'

# %%
# Select several rows by position
df.iloc[[0, 1], :]
# Out:
#                               Type Category             Insitution / Company  \
# Project
# Deep Blue     Specialized Projects    Games  IBM, Carnegie Mellon University
# Stockfish AI  Specialized Projects    Games                              NaN
#
#                                 Developer / Author / Group Lead  \
# Project
# Deep Blue     Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI         Tord Romstad, Marco Costalba, Joona Kiiski
#
#                    Location  Year  \
# Project
# Deep Blue     United States  1985
# Stockfish AI  Norway, Italy  2004
#
#                                                     Description Written in  \
# Project
# Deep Blue     Deep Blue was a chess-playing computer develop...      C/C++
# Stockfish AI  Stockfish is a strong open source UCI chess en...      C/C++
#
#                                                           Image  \
# Project
# Deep Blue     http://upload.wikimedia.org/wikipedia/commons/...
# Stockfish AI  http://upload.wikimedia.org/wikipedia/en/thumb...
#
#                                                  Wikipedia Page  \
# Project
# Deep Blue     http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Stockfish AI     http://en.wikipedia.org/wiki/Stockfish_(chess)
#
#                                         Homepage or Source Code
# Project
# Deep Blue     http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Stockfish AI                     http://www.stockfishchess.org/

# %%
# Select several adjacent columns by position
df.iloc[:, 0:3].head()
# Out:
#                                                       Type  \
# Project
# Deep Blue                             Specialized Projects
# Stockfish AI                          Specialized Projects
# Google Now                            Specialized Projects
# OpenCog        Specialized Projects, Multipurpose Projects
# Apache Mahout                        Multipurpose Projects
#
#                                                  Category  \
# Project
# Deep Blue                                           Games
# Stockfish AI                                        Games
# Google Now                        Knowledge and Reasoning
# OpenCog        Cognitive Architechture, Software Packages
# Apache Mahout                           Software Packages
#
#                           Insitution / Company
# Project
# Deep Blue      IBM, Carnegie Mellon University
# Stockfish AI                               NaN
# Google Now                              Google
# OpenCog                     OpenCog Foundation
# Apache Mahout       Apache Software Foundation

# %%
# Search and replace a value.
# Replace all the NaNs in `Written in` column with `Unknown`.
df.loc[:, 'Written in'].replace(np.nan, 'Unknown')
# Out:
# Project
# Deep Blue                                                             C/C++
# Stockfish AI                                                          C/C++
# Google Now                                                            C/C++
# OpenCog                                               C/C++, Python, Scheme
# Apache Mahout                                                          Java
# CoJACK                                                                 Java
# Neuroph                                                                Java
# RapidMiner                                                             Java
# Weka                                                                   Java
# Encog                                                     Java, .Net, C/C++
# Watson                                                  Java, C/C++, Prolog
# Deeplearning4j                                                   Java, CUDA
# PARRY                                                                  LISP
# 4CAPS                                                                  LISP
# ACT-R                                                                  LISP
# Copycat                                                                LISP
# Mycin                                                                  LISP
# SNePS                                                                  LISP
# Soar                                                                   LISP
# Cyc                                                              LISP, CycL
# SHRDLU                                                  Micro Planner, LISP
# Eurisko                                                         RLL-1, LISP
# Artificial Linguistic Internet Computer Entity            SETL, Java, C/C++
# ELIZA                                                                  SLIP
# Wolfram Alpha                                              Wolfram Language
# Chinook                                                             Unknown
# Blue Brain Project                                                  Unknown
# AIBO                                                                Unknown
# Braina                                                              Unknown
# CALO                                                                Unknown
# CHREST                                                              Unknown
# Cleverbot                                                           Unknown
# Cog                                                                 Unknown
# CLARION                                                             Unknown
# DUAL                                                                Unknown
# EPIC                                                                Unknown
# FORR                                                                Unknown
# FreeHAL                                                             Unknown
# Google Brain                                                        Unknown
# Grok                                                                Unknown
# Procedural Reasoning System                                         Unknown
# Microsoft Cortana                                                   Unknown
# Jabberwacky                                                         Unknown
# Open Mind Common Sense                                              Unknown
# P.A.N.                                                              Unknown
# PreAct                                                              Unknown
# Synthetic Environment for Analysis and Simulations                  Unknown
# R-CAST                                                              Unknown
# Siri                                                                Unknown
# SYSTRAN                                                             Unknown
# TD-Gammon                                                           Unknown
# InfoTame                                                            Unknown
# IDA and LIDA                                                        Unknown
# NuPIC                                                               Unknown
# Name: Written in, dtype: object
