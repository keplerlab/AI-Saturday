# %% [markdown]
# # Dataframes Kung-fu with Pandas
#
# <img style="float: right;" src="data/po.png" width=256>
# **TL;DR**
# - Read CSVs into dataframes
# - Explore dataframe and show statistics
# - Create a dataframe and append to an existing one
# - Indexing and slicing
# - Find and replace
# - Deletion

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading a CSV into dataframe
df = pd.read_csv('data/Major-AI-projects.csv')

# Show column names and number of rows
cols = df.columns.values.tolist()
rows = df.index
print('cols:\n{}\n'.format(', '.join(cols)))
print('num_rows:\n{}\n'.format(len(rows)))
# Out:
# cols:
# Project, Type, Category, Insitution / Company, Developer / Author / Group Lead, Location, Year, Description, Written in, Image, Wikipedia Page, Homepage or Source Code
#
# num_rows:
# 54

# %%
# First five items of the dataframe.
df.head()
# Out:
#          Project                                         Type  \
# 0      Deep Blue                         Specialized Projects
# 1   Stockfish AI                         Specialized Projects
# 2     Google Now                         Specialized Projects
# 3        OpenCog  Specialized Projects, Multipurpose Projects
# 4  Apache Mahout                        Multipurpose Projects
#
#                                      Category  \
# 0                                       Games
# 1                                       Games
# 2                     Knowledge and Reasoning
# 3  Cognitive Architechture, Software Packages
# 4                           Software Packages
#
#               Insitution / Company  \
# 0  IBM, Carnegie Mellon University
# 1                              NaN
# 2                           Google
# 3               OpenCog Foundation
# 4       Apache Software Foundation
#
#                      Developer / Author / Group Lead       Location  Year  \
# 0  Feng-hsiung Hsu, Thomas Anantharaman, Murray C...  United States  1985
# 1         Tord Romstad, Marco Costalba, Joona Kiiski  Norway, Italy  2004
# 2                                                NaN  United States  2012
# 3                                       Ben Goertzel  United States  2008
# 4        Isabel Drost, Grant Ingersoll, Karl Wettin.  United States  2010
#
#                                          Description             Written in  \
# 0  Deep Blue was a chess-playing computer develop...                  C/C++
# 1  Stockfish is a strong open source UCI chess en...                  C/C++
# 2  Google Now is an intelligent personal assistan...                  C/C++
# 3  OpenCog is a project that aims to build an ope...  C/C++, Python, Scheme
# 4  Apache Mahout is a project of the Apache Softw...                   Java
#
#                                                Image  \
# 0  http://upload.wikimedia.org/wikipedia/commons/...
# 1  http://upload.wikimedia.org/wikipedia/en/thumb...
# 2  http://upload.wikimedia.org/wikipedia/en/thumb...
# 3  http://upload.wikimedia.org/wikipedia/en/thumb...
# 4                                                NaN
#
#                                       Wikipedia Page  \
# 0  http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# 1     http://en.wikipedia.org/wiki/Stockfish_(chess)
# 2            http://en.wikipedia.org/wiki/Google_Now
# 3               http://en.wikipedia.org/wiki/OpenCog
# 4         http://en.wikipedia.org/wiki/Apache_Mahout
#
#                              Homepage or Source Code
# 0  http://www-03.ibm.com/ibm/history/ibm100/us/en...
# 1                     http://www.stockfishchess.org/
# 2                     http://google.com/landing/now/
# 3                                http://opencog.org/
# 4                          http://mahout.apache.org/

# %%
# Use pandas.DataFrames.describe() to generate a descriptive statistics.
df.describe()
# Out:
#        Project                  Type                 Category  \
# count       54                    54                       54
# unique      54                     3                       11
# top       EPIC  Specialized Projects  Cognitive Architechture
# freq         1                    45                       15
#
#        Insitution / Company Developer / Author / Group Lead       Location  \
# count                    47                              38             53
# unique                   38                              36             13
# top                     MIT                   Douglas Lenat  United States
# freq                      4                               2             40
#
#         Year                                        Description Written in  \
# count     40                                                 54         25
# unique    27                                                 54         13
# top     2008  Connectionist Learning with Adaptive Rule Indu...       LISP
# freq       3                                                  1          7
#
#                                                     Image  \
# count                                                  16
# unique                                                 16
# top     http://upload.wikimedia.org/wikipedia/en/5/5c/...
# freq                                                    1
#
#                                            Wikipedia Page  \
# count                                                  53
# unique                                                 53
# top     http://en.wikipedia.org/wiki/Artificial_Lingui...
# freq                                                    1
#
#        Homepage or Source Code
# count                       45
# unique                      45
# top        http://opencog.org/
# freq                         1

# %%
# Data shows the major AI projects done by different organizations.
# Let's find out the frequency of projects done for each category.
plt.figure(figsize=(20, 5))
plt.xticks(rotation=45)
df.Category.hist()
plt.title('Frequency of projects per category')
plt.show()

# %%
# Now, we want to add a row to our dataframe.
# This involves creating a new dataframe and appending it to an existing one.
d = {'Category': 'Generative Adversarial Nets', 'Project': ['DCGANs'], 'Year': ['2015']}
df_new = pd.DataFrame(data=d)

df.append(df_new)
# Out:
#                                       Category  \
# 0                                        Games
# 1                                        Games
# 2                      Knowledge and Reasoning
# 3   Cognitive Architechture, Software Packages
# 4                            Software Packages
# 5                      Cognitive Architechture
# 6                            Software Packages
# 7                            Software Packages
# 8                               Cloud Services
# 9                            Software Packages
# 10     Knowledge and Reasoning, Cloud Services
# 11                           Software Packages
# 12                 Natural Language Processing
# 13                     Cognitive Architechture
# 14                     Cognitive Architechture
# 15                     Cognitive Architechture
# 16                     Knowledge and Reasoning
# 17                     Knowledge and Reasoning
# 18                     Cognitive Architechture
# 19                     Knowledge and Reasoning
# 20                 Natural Language Processing
# 21                     Knowledge and Reasoning
# 22                 Natural Language Processing
# 23                 Natural Language Processing
# 24                     Knowledge and Reasoning
# 25                                       Games
# 26                              Brain Inspired
# 27                    Motion and Manipulations
# 28                     Knowledge and Reasoning
# 29                     Cognitive Architechture
# 30                     Cognitive Architechture
# 31                 Natural Language Processing
# 32                    Motion and Manipulations
# 33                     Cognitive Architechture
# 34                     Cognitive Architechture
# 35                     Cognitive Architechture
# 36                     Cognitive Architechture
# 37                                       Games
# 38                              Brain Inspired
# 39                              Cloud Services
# 40                     Cognitive Architechture
# 41                     Knowledge and Reasoning
# 42                 Natural Language Processing
# 43                     Knowledge and Reasoning
# 44                     Knowledge and Reasoning
# 45                     Cognitive Architechture
# 46                                       Other
# 47                     Cognitive Architechture
# 48                     Knowledge and Reasoning
# 49                 Natural Language Processing
# 50                                       Games
# 51                 Natural Language Processing
# 52                     Cognitive Architechture
# 53                              Brain Inspired
# 0                  Generative Adversarial Nets
#
#                                           Description  \
# 0   Deep Blue was a chess-playing computer develop...
# 1   Stockfish is a strong open source UCI chess en...
# 2   Google Now is an intelligent personal assistan...
# 3   OpenCog is a project that aims to build an ope...
# 4   Apache Mahout is a project of the Apache Softw...
# 5   Jack Intelligent Agent JACK is a framework in ...
# 6   Neuroph is an object-oriented neural network f...
# 7   RapidMiner is a software platform developed by...
# 8   Weka (Waikato Environment for Knowledge Analys...
# 9   Encog is a machine learning framework availabl...
# 10  Watson is an artificially intelligent computer...
# 11  Deeplearning4j is an open source deep learning...
# 12  PARRY was an early example of a chatterbot, im...
# 13  4CAPS (Cortical Capacity-Constrained Concurren...
# 14  ACT-R (pronounced act-ARE; short for "Adaptive...
# 15  Copycat is a model of analogy making and human...
# 16  MYCIN was an early expert system that used art...
# 17  SNePS is a knowledge representation, reasoning...
# 18  Soar is a cognitive architecture, created by J...
# 19  Cyc is an artificial intelligence project that...
# 20  SHRDLU was an early natural language understan...
# 21  Eurisko (Gr., I discover) is a program written...
# 22  A.L.I.C.E. (Artificial Linguistic Internet Com...
# 23  ELIZA is a computer program and an early examp...
# 24  Wolfram Alpha (also styled WolframAlpha and Wo...
# 25  Chinook is a computer program that plays check...
# 26  The Blue Brain Project is an attempt to create...
# 27  AIBO (Artificial Intelligence Robot, homonymou...
# 28  Braina is an intelligent personal assistant ap...
# 29  CALO was an artificial intelligence project th...
# 30  CHREST (Chunk Hierarchy and REtrieval STructur...
# 31  Cleverbot is a web application that uses an ar...
# 32  Cog was a project at the Humanoid Robotics Gro...
# 33  Connectionist Learning with Adaptive Rule Indu...
# 34  DUAL is a general cognitive architecture integ...
# 35  EPIC (Executive-Process/Interactive Control) i...
# 36  FORR (FOr the Right Reasons) is a cognitive ar...
# 37  FreeHAL is a distributed computing project to ...
# 38  Google Brain is a deep learning research proje...
# 39  Grok for IT Analytics enables insights into IT...
# 40  In artificial intelligence, a procedural reaso...
# 41  In computing, Cortana is an intelligent person...
# 42  Jabberwacky is a chatterbot created by British...
# 43  Open Mind Common Sense (OMCS) is an artificial...
# 44  P.A.N. (A.K.A.: Poetry Analyzer, Textual Analy...
# 45  PreAct is a cognitive engine technology that i...
# 46  Purdue University's Synthetic Environment for ...
# 47  R-CAST is a group decision support system base...
# 48  Siri /ˈsɪri/ is an application for Apple Inc.'...
# 49  SYSTRAN, founded by Dr. Peter Toma in 1968, is...
# 50  TD-Gammon was a computer backgammon program de...
# 51  Text analysis search engine originally develop...
# 52  The LIDA (Learning Intelligent Distribution Ag...
# 53  The Numenta Platform for Intelligent Computing...
# 0                                                 NaN
#
#                       Developer / Author / Group Lead  \
# 0   Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# 1          Tord Romstad, Marco Costalba, Joona Kiiski
# 2                                                 NaN
# 3                                        Ben Goertzel
# 4         Isabel Drost, Grant Ingersoll, Karl Wettin.
# 5                                                 NaN
# 6                                                 NaN
# 7       Ralf Klinkenberg, Ingo Mierswa, Simon Fischer
# 8                                                 NaN
# 9                                         Jeff Heaton
# 10                                                NaN
# 11                                        Adam Gibson
# 12                                      Kenneth Colby
# 13                      Marcel A. Just, Sashank Varma
# 14                               John Robert Anderson
# 15               Douglas Hofstadter, Melanie Mitchell
# 16  Edward Shortliffe, Bruce Buchanan, Stanley N. ...
# 17                                  Stuart C. Shapiro
# 18          John Laird, Allen Newell, Paul Rosenbloom
# 19                                      Douglas Lenat
# 20                                     Terry Winograd
# 21                                      Douglas Lenat
# 22                                    Richard Wallace
# 23                                  Joseph Weizenbaum
# 24                                                NaN
# 25  Jonathan Schaeffer, Rob Lake, Paul Lu, Martin ...
# 26          Henry Markram, Felix Schürmann, Sean Hill
# 27                                      Toshitada Doi
# 28                                                NaN
# 29                                                NaN
# 30                       Fernand Gobet, Peter C. Lane
# 31                                    Rollo Carpenter
# 32                                                NaN
# 33                                            Ron Sun
# 34                                     Boicho Kokinov
# 35                    David E. Kieras, David E. Meyer
# 36                                                NaN
# 37                                      Tobias Schulz
# 38                              Andrew Ng,  Jeff Dean
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                    Rollo Carpenter
# 43        Marvin Minsky, Push Singh, Catherine Havasi
# 44                               David Benjamin Bowes
# 45                                        Norm Geddes
# 46                                 Alok R. Chaturvedi
# 47                                           John Yen
# 48                                                NaN
# 49                                         Peter Toma
# 50                                     Gerald Tesauro
# 51                                                NaN
# 52                                      Stan Franklin
# 53                                                NaN
# 0                                                 NaN
#
#                               Homepage or Source Code  \
# 0   http://www-03.ibm.com/ibm/history/ibm100/us/en...
# 1                      http://www.stockfishchess.org/
# 2                      http://google.com/landing/now/
# 3                                 http://opencog.org/
# 4                           http://mahout.apache.org/
# 5     http://www.agent-software.com.au/products/jack/
# 6                     http://neuroph.sourceforge.net/
# 7                             https://rapidminer.com/
# 8               http://www.cs.waikato.ac.nz/~ml/weka/
# 9                 http://www.heatonresearch.com/encog
# 10  http://www.ibm.com/smarterplanet/us/en/ibmwatson/
# 11                                 deeplearning4j.org
# 12  http://www.cs.cmu.edu/afs/cs/project/ai-reposi...
# 13           http://www.ccbi.cmu.edu/4CAPS/index.html
# 14                          http://act-r.psy.cmu.edu/
# 15  http://web.cecs.pdx.edu/~mm/how-to-get-copycat...
# 16                                                NaN
# 17                  http://www.cse.buffalo.edu/sneps/
# 18                        http://soar.eecs.umich.edu/
# 19                                http://www.cyc.com/
# 20          http://hci.stanford.edu/~winograd/shrdlu/
# 21  http://citeseerx.ist.psu.edu/viewdoc/download?...
# 22  https://code.google.com/p/aiml-en-us-foundatio...
# 23            https://github.com/jeffshrager/elizagen
# 24                       http://www.wolframalpha.com/
# 25            http://webdocs.cs.ualberta.ca/~chinook/
# 26                          http://bluebrain.epfl.ch/
# 27                        http://www.sony-aibo.co.uk/
# 28                  http://www.brainasoft.com/braina/
# 29                https://pal.sri.com/Plone/framework
# 30                                http://chrest.info/
# 31                          http://www.cleverbot.com/
# 32  http://groups.csail.mit.edu/lbr/humanoid-robot...
# 33       http://www.cogsci.rpi.edu/~rsun/clarion.html
# 34                                                NaN
# 35                                                NaN
# 36  http://www.compsci.hunter.cuny.edu/~epstein/ht...
# 37                          http://freehal.github.io/
# 38                                                NaN
# 39                           http://numenta.com/grok/
# 40                        http://www.ai.sri.com/~prs/
# 41  http://www.windowsphone.com/en-us/how-to/wp8/c...
# 42                        http://www.jabberwacky.com/
# 43                                                NaN
# 44                        http://pan.sourceforge.net/
# 45                                                NaN
# 46  http://www.krannert.purdue.edu/centers/perc/ht...
# 47                                                NaN
# 48                     http://www.apple.com/ios/siri/
# 49                        http://www.systransoft.com/
# 50                                                NaN
# 51                           http://www.infotame.com/
# 52                                                NaN
# 53                                http://numenta.org/
# 0                                                 NaN
#
#                                                 Image  \
# 0   http://upload.wikimedia.org/wikipedia/commons/...
# 1   http://upload.wikimedia.org/wikipedia/en/thumb...
# 2   http://upload.wikimedia.org/wikipedia/en/thumb...
# 3   http://upload.wikimedia.org/wikipedia/en/thumb...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   http://upload.wikimedia.org/wikipedia/commons/...
# 8   http://upload.wikimedia.org/wikipedia/commons/...
# 9   http://upload.wikimedia.org/wikipedia/en/5/5c/...
# 10  http://upload.wikimedia.org/wikipedia/commons/...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  http://wiki.lesswrong.com/mediawiki/images/5/5...
# 22                                                NaN
# 23  http://upload.wikimedia.org/wikipedia/commons/...
# 24  http://upload.wikimedia.org/wikipedia/en/thumb...
# 25                                                NaN
# 26                                                NaN
# 27  http://upload.wikimedia.org/wikipedia/commons/...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  http://www.ai.mit.edu/projects/cog/Pictures/he...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  http://upload.wikimedia.org/wikipedia/en/thumb...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  http://upload.wikimedia.org/wikipedia/en/thumb...
# 49                                                NaN
# 50  http://upload.wikimedia.org/wikipedia/commons/...
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 0                                                 NaN
#
#                                  Insitution / Company        Location  \
# 0                     IBM, Carnegie Mellon University   United States
# 1                                                 NaN   Norway, Italy
# 2                                              Google   United States
# 3                                  OpenCog Foundation   United States
# 4                          Apache Software Foundation   United States
# 5                             Agent Oriented Software       Australia
# 6                              University of Belgrade          Serbia
# 7                   Dortmund University of Technology   United States
# 8                               University of Waikato     New Zealand
# 9                                     Heaton Research   United States
# 10                                                IBM   United States
# 11                                                NaN   United States
# 12                                Stanford University   United States
# 13                         Carnegie Mellon University   United States
# 14                         Carnegie Mellon University   United States
# 15                                 Indiana University   United States
# 16                                Stanford University   United States
# 17            State University of New York at Buffalo   United States
# 18  Carnegie Mellon University, University of Mich...   United States
# 19  Microelectronics and Computer Technology Corpo...   United States
# 20                                                MIT   United States
# 21   Carnegie Mellon University,  Stanford University   United States
# 22                                                NaN   United States
# 23                                                MIT   United States
# 24                                   Wolfram Research   United States
# 25                              University of Alberta          Canada
# 26           École Polytechnique Fédérale de Lausanne     Switzerland
# 27                                               Sony           Japan
# 28                                         Brainasoft           India
# 29                                  SRI International   United States
# 30     Brunel University, University of Hertfordshire  United Kingdom
# 31                                                NaN   United States
# 32                                                MIT   United States
# 33  Rensselaer Polytechnic Institute, University o...   United States
# 34                           New Bulgarian University        Bulgaria
# 35                             University of Michigan   United States
# 36                    The City University of New York   United States
# 37                                                NaN         Germany
# 38                                             Google   United States
# 39                                            Numenta   United States
# 40                                  SRI International   United States
# 41                                          Microsoft   United States
# 42                                                NaN  United Kingdom
# 43                                                MIT   United States
# 44                                                NaN             NaN
# 45                       Applied Systems Intelligence   United States
# 46                                  Purdue University   United States
# 47                      Pennsylvania State University   United States
# 48                                          Siri Inc.   United States
# 49                                            SYSTRAN   United States
# 50                                                IBM   United States
# 51                                                KGB          Russia
# 52                              University of Memphis   United States
# 53                                            Numenta   United States
# 0                                                 NaN             NaN
#
#                                               Project  \
# 0                                           Deep Blue
# 1                                        Stockfish AI
# 2                                          Google Now
# 3                                             OpenCog
# 4                                       Apache Mahout
# 5                                              CoJACK
# 6                                             Neuroph
# 7                                          RapidMiner
# 8                                                Weka
# 9                                               Encog
# 10                                             Watson
# 11                                     Deeplearning4j
# 12                                              PARRY
# 13                                              4CAPS
# 14                                              ACT-R
# 15                                            Copycat
# 16                                              Mycin
# 17                                              SNePS
# 18                                               Soar
# 19                                                Cyc
# 20                                             SHRDLU
# 21                                            Eurisko
# 22     Artificial Linguistic Internet Computer Entity
# 23                                              ELIZA
# 24                                      Wolfram Alpha
# 25                                            Chinook
# 26                                 Blue Brain Project
# 27                                               AIBO
# 28                                             Braina
# 29                                               CALO
# 30                                             CHREST
# 31                                          Cleverbot
# 32                                                Cog
# 33                                            CLARION
# 34                                               DUAL
# 35                                               EPIC
# 36                                               FORR
# 37                                            FreeHAL
# 38                                       Google Brain
# 39                                               Grok
# 40                        Procedural Reasoning System
# 41                                  Microsoft Cortana
# 42                                        Jabberwacky
# 43                             Open Mind Common Sense
# 44                                             P.A.N.
# 45                                             PreAct
# 46  Synthetic Environment for Analysis and Simulat...
# 47                                             R-CAST
# 48                                               Siri
# 49                                            SYSTRAN
# 50                                          TD-Gammon
# 51                                           InfoTame
# 52                                       IDA and LIDA
# 53                                              NuPIC
# 0                                              DCGANs
#
#                                            Type  \
# 0                          Specialized Projects
# 1                          Specialized Projects
# 2                          Specialized Projects
# 3   Specialized Projects, Multipurpose Projects
# 4                         Multipurpose Projects
# 5                          Specialized Projects
# 6                         Multipurpose Projects
# 7                         Multipurpose Projects
# 8                         Multipurpose Projects
# 9                         Multipurpose Projects
# 10  Specialized Projects, Multipurpose Projects
# 11                        Multipurpose Projects
# 12                         Specialized Projects
# 13                         Specialized Projects
# 14                         Specialized Projects
# 15                         Specialized Projects
# 16                         Specialized Projects
# 17                         Specialized Projects
# 18                         Specialized Projects
# 19                         Specialized Projects
# 20                         Specialized Projects
# 21                         Specialized Projects
# 22                         Specialized Projects
# 23                         Specialized Projects
# 24                         Specialized Projects
# 25                         Specialized Projects
# 26                         Specialized Projects
# 27                         Specialized Projects
# 28                         Specialized Projects
# 29                         Specialized Projects
# 30                         Specialized Projects
# 31                         Specialized Projects
# 32                         Specialized Projects
# 33                         Specialized Projects
# 34                         Specialized Projects
# 35                         Specialized Projects
# 36                         Specialized Projects
# 37                         Specialized Projects
# 38                         Specialized Projects
# 39                        Multipurpose Projects
# 40                         Specialized Projects
# 41                         Specialized Projects
# 42                         Specialized Projects
# 43                         Specialized Projects
# 44                         Specialized Projects
# 45                         Specialized Projects
# 46                         Specialized Projects
# 47                         Specialized Projects
# 48                         Specialized Projects
# 49                         Specialized Projects
# 50                         Specialized Projects
# 51                         Specialized Projects
# 52                         Specialized Projects
# 53                         Specialized Projects
# 0                                           NaN
#
#                                        Wikipedia Page             Written in  \
# 0   http://en.wikipedia.org/wiki/Deep_Blue_(chess_...                  C/C++
# 1      http://en.wikipedia.org/wiki/Stockfish_(chess)                  C/C++
# 2             http://en.wikipedia.org/wiki/Google_Now                  C/C++
# 3                http://en.wikipedia.org/wiki/OpenCog  C/C++, Python, Scheme
# 4          http://en.wikipedia.org/wiki/Apache_Mahout                   Java
# 5   http://en.wikipedia.org/wiki/JACK_Intelligent_...                   Java
# 6                http://en.wikipedia.org/wiki/Neuroph                   Java
# 7             http://en.wikipedia.org/wiki/RapidMiner                   Java
# 8   http://en.wikipedia.org/wiki/Weka_(machine_lea...                   Java
# 9                  http://en.wikipedia.org/wiki/Encog      Java, .Net, C/C++
# 10     http://en.wikipedia.org/wiki/Watson_(computer)    Java, C/C++, Prolog
# 11        http://en.wikipedia.org/wiki/Deeplearning4j             Java, CUDA
# 12                 http://en.wikipedia.org/wiki/PARRY                   LISP
# 13                 http://en.wikipedia.org/wiki/4CAPS                   LISP
# 14                 http://en.wikipedia.org/wiki/ACT-R                   LISP
# 15    http://en.wikipedia.org/wiki/Copycat_(software)                   LISP
# 16                 http://en.wikipedia.org/wiki/Mycin                   LISP
# 17                 http://en.wikipedia.org/wiki/SNePS                   LISP
# 18  http://en.wikipedia.org/wiki/Soar_(cognitive_a...                   LISP
# 19                   http://en.wikipedia.org/wiki/Cyc             LISP, CycL
# 20                http://en.wikipedia.org/wiki/SHRDLU    Micro Planner, LISP
# 21               http://en.wikipedia.org/wiki/Eurisko            RLL-1, LISP
# 22  http://en.wikipedia.org/wiki/Artificial_Lingui...      SETL, Java, C/C++
# 23                 http://en.wikipedia.org/wiki/ELIZA                   SLIP
# 24         http://en.wikipedia.org/wiki/Wolfram_Alpha       Wolfram Language
# 25  http://en.wikipedia.org/wiki/Chinook_(draughts...                    NaN
# 26    http://en.wikipedia.org/wiki/Blue_Brain_Project                    NaN
# 27                  http://en.wikipedia.org/wiki/AIBO                    NaN
# 28                http://en.wikipedia.org/wiki/Braina                    NaN
# 29                  http://en.wikipedia.org/wiki/CALO                    NaN
# 30                http://en.wikipedia.org/wiki/CHREST                    NaN
# 31             http://en.wikipedia.org/wiki/Cleverbot                    NaN
# 32         http://en.wikipedia.org/wiki/Cog_(project)                    NaN
# 33  http://en.wikipedia.org/wiki/CLARION_(cognitiv...                    NaN
# 34  http://en.wikipedia.org/wiki/DUAL_(cognitive_a...                    NaN
# 35  http://en.wikipedia.org/wiki/EPIC_(cognitive_a...                    NaN
# 36                  http://en.wikipedia.org/wiki/FORR                    NaN
# 37               http://en.wikipedia.org/wiki/FreeHAL                    NaN
# 38          http://en.wikipedia.org/wiki/Google_Brain                    NaN
# 39        http://en.wikipedia.org/wiki/Grok_(company)                    NaN
# 40  http://en.wikipedia.org/wiki/Procedural_Reason...                    NaN
# 41     http://en.wikipedia.org/wiki/Microsoft_Cortana                    NaN
# 42           http://en.wikipedia.org/wiki/Jabberwacky                    NaN
# 43  http://en.wikipedia.org/wiki/Open_Mind_Common_...                    NaN
# 44                http://en.wikipedia.org/wiki/P.A.N.                    NaN
# 45                http://en.wikipedia.org/wiki/PreAct                    NaN
# 46  http://en.wikipedia.org/wiki/Synthetic_Environ...                    NaN
# 47                http://en.wikipedia.org/wiki/R-CAST                    NaN
# 48                  http://en.wikipedia.org/wiki/Siri                    NaN
# 49               http://en.wikipedia.org/wiki/SYSTRAN                    NaN
# 50             http://en.wikipedia.org/wiki/TD-Gammon                    NaN
# 51                                                NaN                    NaN
# 52  http://en.wikipedia.org/wiki/LIDA_(cognitive_a...                    NaN
# 53  http://en.wikipedia.org/wiki/Numenta#The_NuPIC...                    NaN
# 0                                                 NaN                    NaN
#
#      Year
# 0    1985
# 1    2004
# 2    2012
# 3    2008
# 4    2010
# 5    1997
# 6    2008
# 7    2001
# 8    1993
# 9    2008
# 10   2005
# 11    NaN
# 12   1972
# 13   2006
# 14   1993
# 15   1988
# 16  1970s
# 17    NaN
# 18   1983
# 19   1984
# 20   1968
# 21   1976
# 22   1995
# 23   1964
# 24   2009
# 25   1989
# 26   2005
# 27   1998
# 28    NaN
# 29   2003
# 30   1992
# 31   1997
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37   2006
# 38   2001
# 39    NaN
# 40    NaN
# 41   2014
# 42   1988
# 43   1999
# 44   2005
# 45    NaN
# 46   2004
# 47    NaN
# 48   2010
# 49   1968
# 50   1992
# 51    NaN
# 52    NaN
# 53   2007
# 0    2015

# %% [markdown]
# ## Indexing like a Ninja
#
# Guidelines:
# - use `.loc` for labels
# - use `.iloc` for positions
# - explicitly designate both rows and columns

# %%
""" Select a column by name """
# We add `:` to say that we are interested in all the rows.
# We add the column name to indicate the column we are interested in.
df.loc[:, 'Project'].head(10)
# Out:
# 0        Deep Blue
# 1     Stockfish AI
# 2       Google Now
# 3          OpenCog
# 4    Apache Mahout
# 5           CoJACK
# 6          Neuroph
# 7       RapidMiner
# 8             Weka
# 9            Encog
# Name: Project, dtype: object

# %%
# Note that the previous method returns the row as a Series.
# If we are only interested in the values we can do the following which will return a numpy array.
df.loc[:, 'Project'].values
# Out:
# array(['Deep Blue', 'Stockfish AI', 'Google Now', 'OpenCog',
#        'Apache Mahout', 'CoJACK', 'Neuroph', 'RapidMiner', 'Weka', 'Encog',
#        'Watson', 'Deeplearning4j', 'PARRY', '4CAPS', 'ACT-R', 'Copycat',
#        'Mycin', 'SNePS', 'Soar', 'Cyc', 'SHRDLU', 'Eurisko',
#        'Artificial Linguistic Internet Computer Entity', 'ELIZA',
#        'Wolfram Alpha', 'Chinook', 'Blue Brain Project', 'AIBO', 'Braina',
#        'CALO', 'CHREST', 'Cleverbot', 'Cog', 'CLARION', 'DUAL', 'EPIC',
#        'FORR', 'FreeHAL', 'Google Brain', 'Grok',
#        'Procedural Reasoning System', 'Microsoft Cortana', 'Jabberwacky',
#        'Open Mind Common Sense', 'P.A.N.', 'PreAct',
#        'Synthetic Environment for Analysis and Simulations', 'R-CAST',
#        'Siri', 'SYSTRAN', 'TD-Gammon', 'InfoTame', 'IDA and LIDA', 'NuPIC'], dtype=object)

# %%
# Till now we were using row numbers as index.
# We can specify a column to serve as index for our dataframe.
df.set_index('Project', inplace=True)

# %%
# Now if we want to select a particular value from the dataframe, say, which year the `Google Now` project was taken.
# We can do that easily.
df.loc['Google Now', 'Year']
# Out:
# '2012'

# %%
# Select several rows by labels - pass a list of labels in the row position.
df.loc[['Google Now', 'Deep Blue', 'Stockfish AI'], 'Year']
# Out:
# Project
# Google Now      2012
# Deep Blue       1985
# Stockfish AI    2004
# Name: Year, dtype: object

# %%
# We can also do the same for columns.
df.loc[['Google Now', 'Deep Blue', 'Stockfish AI'], ['Year', 'Written in']]
# Out:
#               Year Written in
# Project
# Google Now    2012      C/C++
# Deep Blue     1985      C/C++
# Stockfish AI  2004      C/C++

# %%
# Select several consecutive columns by label.
df.loc[:, 'Category': 'Written in'].head()
# Out:
#                                                  Category  \
# Project
# Deep Blue                                           Games
# Stockfish AI                                        Games
# Google Now                        Knowledge and Reasoning
# OpenCog        Cognitive Architechture, Software Packages
# Apache Mahout                           Software Packages
#
#                           Insitution / Company  \
# Project
# Deep Blue      IBM, Carnegie Mellon University
# Stockfish AI                               NaN
# Google Now                              Google
# OpenCog                     OpenCog Foundation
# Apache Mahout       Apache Software Foundation
#
#                                  Developer / Author / Group Lead  \
# Project
# Deep Blue      Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI          Tord Romstad, Marco Costalba, Joona Kiiski
# Google Now                                                   NaN
# OpenCog                                             Ben Goertzel
# Apache Mahout        Isabel Drost, Grant Ingersoll, Karl Wettin.
#
#                     Location  Year  \
# Project
# Deep Blue      United States  1985
# Stockfish AI   Norway, Italy  2004
# Google Now     United States  2012
# OpenCog        United States  2008
# Apache Mahout  United States  2010
#
#                                                      Description  \
# Project
# Deep Blue      Deep Blue was a chess-playing computer develop...
# Stockfish AI   Stockfish is a strong open source UCI chess en...
# Google Now     Google Now is an intelligent personal assistan...
# OpenCog        OpenCog is a project that aims to build an ope...
# Apache Mahout  Apache Mahout is a project of the Apache Softw...
#
#                           Written in
# Project
# Deep Blue                      C/C++
# Stockfish AI                   C/C++
# Google Now                     C/C++
# OpenCog        C/C++, Python, Scheme
# Apache Mahout                   Java

# %%
# Select rows based on column value.
# Select all the projects that were taken in the year 2004.
df.loc[df.loc[:, 'Year'] == '2004', :]
# Out:
#                                                                     Type  \
# Project
# Stockfish AI                                        Specialized Projects
# Synthetic Environment for Analysis and Simulations  Specialized Projects
#
#                                                    Category  \
# Project
# Stockfish AI                                          Games
# Synthetic Environment for Analysis and Simulations    Other
#
#                                                    Insitution / Company  \
# Project
# Stockfish AI                                                        NaN
# Synthetic Environment for Analysis and Simulations    Purdue University
#
#                                                                Developer / Author / Group Lead  \
# Project
# Stockfish AI                                        Tord Romstad, Marco Costalba, Joona Kiiski
# Synthetic Environment for Analysis and Simulations                          Alok R. Chaturvedi
#
#                                                          Location  Year  \
# Project
# Stockfish AI                                        Norway, Italy  2004
# Synthetic Environment for Analysis and Simulations  United States  2004
#
#                                                                                           Description  \
# Project
# Stockfish AI                                        Stockfish is a strong open source UCI chess en...
# Synthetic Environment for Analysis and Simulations  Purdue University's Synthetic Environment for ...
#
#                                                    Written in  \
# Project
# Stockfish AI                                            C/C++
# Synthetic Environment for Analysis and Simulations        NaN
#
#                                                                                                 Image  \
# Project
# Stockfish AI                                        http://upload.wikimedia.org/wikipedia/en/thumb...
# Synthetic Environment for Analysis and Simulations                                                NaN
#
#                                                                                        Wikipedia Page  \
# Project
# Stockfish AI                                           http://en.wikipedia.org/wiki/Stockfish_(chess)
# Synthetic Environment for Analysis and Simulations  http://en.wikipedia.org/wiki/Synthetic_Environ...
#
#                                                                               Homepage or Source Code
# Project
# Stockfish AI                                                           http://www.stockfishchess.org/
# Synthetic Environment for Analysis and Simulations  http://www.krannert.purdue.edu/centers/perc/ht...

# %%
# Select a row by position.
df.iloc[0, :]
# Out:
# Type                                                            Specialized Projects
# Category                                                                       Games
# Insitution / Company                                 IBM, Carnegie Mellon University
# Developer / Author / Group Lead    Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Location                                                               United States
# Year                                                                            1985
# Description                        Deep Blue was a chess-playing computer develop...
# Written in                                                                     C/C++
# Image                              http://upload.wikimedia.org/wikipedia/commons/...
# Wikipedia Page                     http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Homepage or Source Code            http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Name: Deep Blue, dtype: object

# %%
# Select a column by position
# Note that we are using the 'Project' column as index. So, column `Type' becomes the 0th column.
df.iloc[:, 0]
# Out:
# Project
# Deep Blue                                                                    Specialized Projects
# Stockfish AI                                                                 Specialized Projects
# Google Now                                                                   Specialized Projects
# OpenCog                                               Specialized Projects, Multipurpose Projects
# Apache Mahout                                                               Multipurpose Projects
# CoJACK                                                                       Specialized Projects
# Neuroph                                                                     Multipurpose Projects
# RapidMiner                                                                  Multipurpose Projects
# Weka                                                                        Multipurpose Projects
# Encog                                                                       Multipurpose Projects
# Watson                                                Specialized Projects, Multipurpose Projects
# Deeplearning4j                                                              Multipurpose Projects
# PARRY                                                                        Specialized Projects
# 4CAPS                                                                        Specialized Projects
# ACT-R                                                                        Specialized Projects
# Copycat                                                                      Specialized Projects
# Mycin                                                                        Specialized Projects
# SNePS                                                                        Specialized Projects
# Soar                                                                         Specialized Projects
# Cyc                                                                          Specialized Projects
# SHRDLU                                                                       Specialized Projects
# Eurisko                                                                      Specialized Projects
# Artificial Linguistic Internet Computer Entity                               Specialized Projects
# ELIZA                                                                        Specialized Projects
# Wolfram Alpha                                                                Specialized Projects
# Chinook                                                                      Specialized Projects
# Blue Brain Project                                                           Specialized Projects
# AIBO                                                                         Specialized Projects
# Braina                                                                       Specialized Projects
# CALO                                                                         Specialized Projects
# CHREST                                                                       Specialized Projects
# Cleverbot                                                                    Specialized Projects
# Cog                                                                          Specialized Projects
# CLARION                                                                      Specialized Projects
# DUAL                                                                         Specialized Projects
# EPIC                                                                         Specialized Projects
# FORR                                                                         Specialized Projects
# FreeHAL                                                                      Specialized Projects
# Google Brain                                                                 Specialized Projects
# Grok                                                                        Multipurpose Projects
# Procedural Reasoning System                                                  Specialized Projects
# Microsoft Cortana                                                            Specialized Projects
# Jabberwacky                                                                  Specialized Projects
# Open Mind Common Sense                                                       Specialized Projects
# P.A.N.                                                                       Specialized Projects
# PreAct                                                                       Specialized Projects
# Synthetic Environment for Analysis and Simulations                           Specialized Projects
# R-CAST                                                                       Specialized Projects
# Siri                                                                         Specialized Projects
# SYSTRAN                                                                      Specialized Projects
# TD-Gammon                                                                    Specialized Projects
# InfoTame                                                                     Specialized Projects
# IDA and LIDA                                                                 Specialized Projects
# NuPIC                                                                        Specialized Projects
# Name: Type, dtype: object

# %%
# Pick up a single value
df.iloc[0, 2]
# Out:
# 'IBM, Carnegie Mellon University'

# %%
# Select several rows by position
df.iloc[[0, 1], :]
# Out:
#                               Type Category             Insitution / Company  \
# Project
# Deep Blue     Specialized Projects    Games  IBM, Carnegie Mellon University
# Stockfish AI  Specialized Projects    Games                              NaN
#
#                                 Developer / Author / Group Lead  \
# Project
# Deep Blue     Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI         Tord Romstad, Marco Costalba, Joona Kiiski
#
#                    Location  Year  \
# Project
# Deep Blue     United States  1985
# Stockfish AI  Norway, Italy  2004
#
#                                                     Description Written in  \
# Project
# Deep Blue     Deep Blue was a chess-playing computer develop...      C/C++
# Stockfish AI  Stockfish is a strong open source UCI chess en...      C/C++
#
#                                                           Image  \
# Project
# Deep Blue     http://upload.wikimedia.org/wikipedia/commons/...
# Stockfish AI  http://upload.wikimedia.org/wikipedia/en/thumb...
#
#                                                  Wikipedia Page  \
# Project
# Deep Blue     http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Stockfish AI     http://en.wikipedia.org/wiki/Stockfish_(chess)
#
#                                         Homepage or Source Code
# Project
# Deep Blue     http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Stockfish AI                     http://www.stockfishchess.org/

# %%
# Select several adjacent columns by position
df.iloc[:, 0:3].head()
# Out:
#                                                       Type  \
# Project
# Deep Blue                             Specialized Projects
# Stockfish AI                          Specialized Projects
# Google Now                            Specialized Projects
# OpenCog        Specialized Projects, Multipurpose Projects
# Apache Mahout                        Multipurpose Projects
#
#                                                  Category  \
# Project
# Deep Blue                                           Games
# Stockfish AI                                        Games
# Google Now                        Knowledge and Reasoning
# OpenCog        Cognitive Architechture, Software Packages
# Apache Mahout                           Software Packages
#
#                           Insitution / Company
# Project
# Deep Blue      IBM, Carnegie Mellon University
# Stockfish AI                               NaN
# Google Now                              Google
# OpenCog                     OpenCog Foundation
# Apache Mahout       Apache Software Foundation

# %%
# Search and replace a value.
# Replace all the NaNs in `Written in` column with `Unknown`.
df.loc[:, 'Written in'].replace(np.nan, 'Unknown')
# Out:
# Project
# Deep Blue                                                             C/C++
# Stockfish AI                                                          C/C++
# Google Now                                                            C/C++
# OpenCog                                               C/C++, Python, Scheme
# Apache Mahout                                                          Java
# CoJACK                                                                 Java
# Neuroph                                                                Java
# RapidMiner                                                             Java
# Weka                                                                   Java
# Encog                                                     Java, .Net, C/C++
# Watson                                                  Java, C/C++, Prolog
# Deeplearning4j                                                   Java, CUDA
# PARRY                                                                  LISP
# 4CAPS                                                                  LISP
# ACT-R                                                                  LISP
# Copycat                                                                LISP
# Mycin                                                                  LISP
# SNePS                                                                  LISP
# Soar                                                                   LISP
# Cyc                                                              LISP, CycL
# SHRDLU                                                  Micro Planner, LISP
# Eurisko                                                         RLL-1, LISP
# Artificial Linguistic Internet Computer Entity            SETL, Java, C/C++
# ELIZA                                                                  SLIP
# Wolfram Alpha                                              Wolfram Language
# Chinook                                                             Unknown
# Blue Brain Project                                                  Unknown
# AIBO                                                                Unknown
# Braina                                                              Unknown
# CALO                                                                Unknown
# CHREST                                                              Unknown
# Cleverbot                                                           Unknown
# Cog                                                                 Unknown
# CLARION                                                             Unknown
# DUAL                                                                Unknown
# EPIC                                                                Unknown
# FORR                                                                Unknown
# FreeHAL                                                             Unknown
# Google Brain                                                        Unknown
# Grok                                                                Unknown
# Procedural Reasoning System                                         Unknown
# Microsoft Cortana                                                   Unknown
# Jabberwacky                                                         Unknown
# Open Mind Common Sense                                              Unknown
# P.A.N.                                                              Unknown
# PreAct                                                              Unknown
# Synthetic Environment for Analysis and Simulations                  Unknown
# R-CAST                                                              Unknown
# Siri                                                                Unknown
# SYSTRAN                                                             Unknown
# TD-Gammon                                                           Unknown
# InfoTame                                                            Unknown
# IDA and LIDA                                                        Unknown
# NuPIC                                                               Unknown
# Name: Written in, dtype: object

# %%
# Delete a column from the dataframe.
df.drop('Image', axis=1) # Alternative: df.drop(columns='Image')
# Out:
#                                                                                            Type  \
# Project
# Deep Blue                                                                  Specialized Projects
# Stockfish AI                                                               Specialized Projects
# Google Now                                                                 Specialized Projects
# OpenCog                                             Specialized Projects, Multipurpose Projects
# Apache Mahout                                                             Multipurpose Projects
# CoJACK                                                                     Specialized Projects
# Neuroph                                                                   Multipurpose Projects
# RapidMiner                                                                Multipurpose Projects
# Weka                                                                      Multipurpose Projects
# Encog                                                                     Multipurpose Projects
# Watson                                              Specialized Projects, Multipurpose Projects
# Deeplearning4j                                                            Multipurpose Projects
# PARRY                                                                      Specialized Projects
# 4CAPS                                                                      Specialized Projects
# ACT-R                                                                      Specialized Projects
# Copycat                                                                    Specialized Projects
# Mycin                                                                      Specialized Projects
# SNePS                                                                      Specialized Projects
# Soar                                                                       Specialized Projects
# Cyc                                                                        Specialized Projects
# SHRDLU                                                                     Specialized Projects
# Eurisko                                                                    Specialized Projects
# Artificial Linguistic Internet Computer Entity                             Specialized Projects
# ELIZA                                                                      Specialized Projects
# Wolfram Alpha                                                              Specialized Projects
# Chinook                                                                    Specialized Projects
# Blue Brain Project                                                         Specialized Projects
# AIBO                                                                       Specialized Projects
# Braina                                                                     Specialized Projects
# CALO                                                                       Specialized Projects
# CHREST                                                                     Specialized Projects
# Cleverbot                                                                  Specialized Projects
# Cog                                                                        Specialized Projects
# CLARION                                                                    Specialized Projects
# DUAL                                                                       Specialized Projects
# EPIC                                                                       Specialized Projects
# FORR                                                                       Specialized Projects
# FreeHAL                                                                    Specialized Projects
# Google Brain                                                               Specialized Projects
# Grok                                                                      Multipurpose Projects
# Procedural Reasoning System                                                Specialized Projects
# Microsoft Cortana                                                          Specialized Projects
# Jabberwacky                                                                Specialized Projects
# Open Mind Common Sense                                                     Specialized Projects
# P.A.N.                                                                     Specialized Projects
# PreAct                                                                     Specialized Projects
# Synthetic Environment for Analysis and Simulations                         Specialized Projects
# R-CAST                                                                     Specialized Projects
# Siri                                                                       Specialized Projects
# SYSTRAN                                                                    Specialized Projects
# TD-Gammon                                                                  Specialized Projects
# InfoTame                                                                   Specialized Projects
# IDA and LIDA                                                               Specialized Projects
# NuPIC                                                                      Specialized Projects
#
#                                                                                       Category  \
# Project
# Deep Blue                                                                                Games
# Stockfish AI                                                                             Games
# Google Now                                                             Knowledge and Reasoning
# OpenCog                                             Cognitive Architechture, Software Packages
# Apache Mahout                                                                Software Packages
# CoJACK                                                                 Cognitive Architechture
# Neuroph                                                                      Software Packages
# RapidMiner                                                                   Software Packages
# Weka                                                                            Cloud Services
# Encog                                                                        Software Packages
# Watson                                                 Knowledge and Reasoning, Cloud Services
# Deeplearning4j                                                               Software Packages
# PARRY                                                              Natural Language Processing
# 4CAPS                                                                  Cognitive Architechture
# ACT-R                                                                  Cognitive Architechture
# Copycat                                                                Cognitive Architechture
# Mycin                                                                  Knowledge and Reasoning
# SNePS                                                                  Knowledge and Reasoning
# Soar                                                                   Cognitive Architechture
# Cyc                                                                    Knowledge and Reasoning
# SHRDLU                                                             Natural Language Processing
# Eurisko                                                                Knowledge and Reasoning
# Artificial Linguistic Internet Computer Entity                     Natural Language Processing
# ELIZA                                                              Natural Language Processing
# Wolfram Alpha                                                          Knowledge and Reasoning
# Chinook                                                                                  Games
# Blue Brain Project                                                              Brain Inspired
# AIBO                                                                  Motion and Manipulations
# Braina                                                                 Knowledge and Reasoning
# CALO                                                                   Cognitive Architechture
# CHREST                                                                 Cognitive Architechture
# Cleverbot                                                          Natural Language Processing
# Cog                                                                   Motion and Manipulations
# CLARION                                                                Cognitive Architechture
# DUAL                                                                   Cognitive Architechture
# EPIC                                                                   Cognitive Architechture
# FORR                                                                   Cognitive Architechture
# FreeHAL                                                                                  Games
# Google Brain                                                                    Brain Inspired
# Grok                                                                            Cloud Services
# Procedural Reasoning System                                            Cognitive Architechture
# Microsoft Cortana                                                      Knowledge and Reasoning
# Jabberwacky                                                        Natural Language Processing
# Open Mind Common Sense                                                 Knowledge and Reasoning
# P.A.N.                                                                 Knowledge and Reasoning
# PreAct                                                                 Cognitive Architechture
# Synthetic Environment for Analysis and Simulations                                       Other
# R-CAST                                                                 Cognitive Architechture
# Siri                                                                   Knowledge and Reasoning
# SYSTRAN                                                            Natural Language Processing
# TD-Gammon                                                                                Games
# InfoTame                                                           Natural Language Processing
# IDA and LIDA                                                           Cognitive Architechture
# NuPIC                                                                           Brain Inspired
#
#                                                                                  Insitution / Company  \
# Project
# Deep Blue                                                             IBM, Carnegie Mellon University
# Stockfish AI                                                                                      NaN
# Google Now                                                                                     Google
# OpenCog                                                                            OpenCog Foundation
# Apache Mahout                                                              Apache Software Foundation
# CoJACK                                                                        Agent Oriented Software
# Neuroph                                                                        University of Belgrade
# RapidMiner                                                          Dortmund University of Technology
# Weka                                                                            University of Waikato
# Encog                                                                                 Heaton Research
# Watson                                                                                            IBM
# Deeplearning4j                                                                                    NaN
# PARRY                                                                             Stanford University
# 4CAPS                                                                      Carnegie Mellon University
# ACT-R                                                                      Carnegie Mellon University
# Copycat                                                                            Indiana University
# Mycin                                                                             Stanford University
# SNePS                                                         State University of New York at Buffalo
# Soar                                                Carnegie Mellon University, University of Mich...
# Cyc                                                 Microelectronics and Computer Technology Corpo...
# SHRDLU                                                                                            MIT
# Eurisko                                              Carnegie Mellon University,  Stanford University
# Artificial Linguistic Internet Computer Entity                                                    NaN
# ELIZA                                                                                             MIT
# Wolfram Alpha                                                                        Wolfram Research
# Chinook                                                                         University of Alberta
# Blue Brain Project                                           École Polytechnique Fédérale de Lausanne
# AIBO                                                                                             Sony
# Braina                                                                                     Brainasoft
# CALO                                                                                SRI International
# CHREST                                                 Brunel University, University of Hertfordshire
# Cleverbot                                                                                         NaN
# Cog                                                                                               MIT
# CLARION                                             Rensselaer Polytechnic Institute, University o...
# DUAL                                                                         New Bulgarian University
# EPIC                                                                           University of Michigan
# FORR                                                                  The City University of New York
# FreeHAL                                                                                           NaN
# Google Brain                                                                                   Google
# Grok                                                                                          Numenta
# Procedural Reasoning System                                                         SRI International
# Microsoft Cortana                                                                           Microsoft
# Jabberwacky                                                                                       NaN
# Open Mind Common Sense                                                                            MIT
# P.A.N.                                                                                            NaN
# PreAct                                                                   Applied Systems Intelligence
# Synthetic Environment for Analysis and Simulations                                  Purdue University
# R-CAST                                                                  Pennsylvania State University
# Siri                                                                                        Siri Inc.
# SYSTRAN                                                                                       SYSTRAN
# TD-Gammon                                                                                         IBM
# InfoTame                                                                                          KGB
# IDA and LIDA                                                                    University of Memphis
# NuPIC                                                                                         Numenta
#
#                                                                       Developer / Author / Group Lead  \
# Project
# Deep Blue                                           Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI                                               Tord Romstad, Marco Costalba, Joona Kiiski
# Google Now                                                                                        NaN
# OpenCog                                                                                  Ben Goertzel
# Apache Mahout                                             Isabel Drost, Grant Ingersoll, Karl Wettin.
# CoJACK                                                                                            NaN
# Neuroph                                                                                           NaN
# RapidMiner                                              Ralf Klinkenberg, Ingo Mierswa, Simon Fischer
# Weka                                                                                              NaN
# Encog                                                                                     Jeff Heaton
# Watson                                                                                            NaN
# Deeplearning4j                                                                            Adam Gibson
# PARRY                                                                                   Kenneth Colby
# 4CAPS                                                                   Marcel A. Just, Sashank Varma
# ACT-R                                                                            John Robert Anderson
# Copycat                                                          Douglas Hofstadter, Melanie Mitchell
# Mycin                                               Edward Shortliffe, Bruce Buchanan, Stanley N. ...
# SNePS                                                                               Stuart C. Shapiro
# Soar                                                        John Laird, Allen Newell, Paul Rosenbloom
# Cyc                                                                                     Douglas Lenat
# SHRDLU                                                                                 Terry Winograd
# Eurisko                                                                                 Douglas Lenat
# Artificial Linguistic Internet Computer Entity                                        Richard Wallace
# ELIZA                                                                               Joseph Weizenbaum
# Wolfram Alpha                                                                                     NaN
# Chinook                                             Jonathan Schaeffer, Rob Lake, Paul Lu, Martin ...
# Blue Brain Project                                          Henry Markram, Felix Schürmann, Sean Hill
# AIBO                                                                                    Toshitada Doi
# Braina                                                                                            NaN
# CALO                                                                                              NaN
# CHREST                                                                   Fernand Gobet, Peter C. Lane
# Cleverbot                                                                             Rollo Carpenter
# Cog                                                                                               NaN
# CLARION                                                                                       Ron Sun
# DUAL                                                                                   Boicho Kokinov
# EPIC                                                                  David E. Kieras, David E. Meyer
# FORR                                                                                              NaN
# FreeHAL                                                                                 Tobias Schulz
# Google Brain                                                                    Andrew Ng,  Jeff Dean
# Grok                                                                                              NaN
# Procedural Reasoning System                                                                       NaN
# Microsoft Cortana                                                                                 NaN
# Jabberwacky                                                                           Rollo Carpenter
# Open Mind Common Sense                                    Marvin Minsky, Push Singh, Catherine Havasi
# P.A.N.                                                                           David Benjamin Bowes
# PreAct                                                                                    Norm Geddes
# Synthetic Environment for Analysis and Simulations                                 Alok R. Chaturvedi
# R-CAST                                                                                       John Yen
# Siri                                                                                              NaN
# SYSTRAN                                                                                    Peter Toma
# TD-Gammon                                                                              Gerald Tesauro
# InfoTame                                                                                          NaN
# IDA and LIDA                                                                            Stan Franklin
# NuPIC                                                                                             NaN
#
#                                                           Location   Year  \
# Project
# Deep Blue                                            United States   1985
# Stockfish AI                                         Norway, Italy   2004
# Google Now                                           United States   2012
# OpenCog                                              United States   2008
# Apache Mahout                                        United States   2010
# CoJACK                                                   Australia   1997
# Neuroph                                                     Serbia   2008
# RapidMiner                                           United States   2001
# Weka                                                   New Zealand   1993
# Encog                                                United States   2008
# Watson                                               United States   2005
# Deeplearning4j                                       United States    NaN
# PARRY                                                United States   1972
# 4CAPS                                                United States   2006
# ACT-R                                                United States   1993
# Copycat                                              United States   1988
# Mycin                                                United States  1970s
# SNePS                                                United States    NaN
# Soar                                                 United States   1983
# Cyc                                                  United States   1984
# SHRDLU                                               United States   1968
# Eurisko                                              United States   1976
# Artificial Linguistic Internet Computer Entity       United States   1995
# ELIZA                                                United States   1964
# Wolfram Alpha                                        United States   2009
# Chinook                                                     Canada   1989
# Blue Brain Project                                     Switzerland   2005
# AIBO                                                         Japan   1998
# Braina                                                       India    NaN
# CALO                                                 United States   2003
# CHREST                                              United Kingdom   1992
# Cleverbot                                            United States   1997
# Cog                                                  United States    NaN
# CLARION                                              United States    NaN
# DUAL                                                      Bulgaria    NaN
# EPIC                                                 United States    NaN
# FORR                                                 United States    NaN
# FreeHAL                                                    Germany   2006
# Google Brain                                         United States   2001
# Grok                                                 United States    NaN
# Procedural Reasoning System                          United States    NaN
# Microsoft Cortana                                    United States   2014
# Jabberwacky                                         United Kingdom   1988
# Open Mind Common Sense                               United States   1999
# P.A.N.                                                         NaN   2005
# PreAct                                               United States    NaN
# Synthetic Environment for Analysis and Simulations   United States   2004
# R-CAST                                               United States    NaN
# Siri                                                 United States   2010
# SYSTRAN                                              United States   1968
# TD-Gammon                                            United States   1992
# InfoTame                                                    Russia    NaN
# IDA and LIDA                                         United States    NaN
# NuPIC                                                United States   2007
#
#                                                                                           Description  \
# Project
# Deep Blue                                           Deep Blue was a chess-playing computer develop...
# Stockfish AI                                        Stockfish is a strong open source UCI chess en...
# Google Now                                          Google Now is an intelligent personal assistan...
# OpenCog                                             OpenCog is a project that aims to build an ope...
# Apache Mahout                                       Apache Mahout is a project of the Apache Softw...
# CoJACK                                              Jack Intelligent Agent JACK is a framework in ...
# Neuroph                                             Neuroph is an object-oriented neural network f...
# RapidMiner                                          RapidMiner is a software platform developed by...
# Weka                                                Weka (Waikato Environment for Knowledge Analys...
# Encog                                               Encog is a machine learning framework availabl...
# Watson                                              Watson is an artificially intelligent computer...
# Deeplearning4j                                      Deeplearning4j is an open source deep learning...
# PARRY                                               PARRY was an early example of a chatterbot, im...
# 4CAPS                                               4CAPS (Cortical Capacity-Constrained Concurren...
# ACT-R                                               ACT-R (pronounced act-ARE; short for "Adaptive...
# Copycat                                             Copycat is a model of analogy making and human...
# Mycin                                               MYCIN was an early expert system that used art...
# SNePS                                               SNePS is a knowledge representation, reasoning...
# Soar                                                Soar is a cognitive architecture, created by J...
# Cyc                                                 Cyc is an artificial intelligence project that...
# SHRDLU                                              SHRDLU was an early natural language understan...
# Eurisko                                             Eurisko (Gr., I discover) is a program written...
# Artificial Linguistic Internet Computer Entity      A.L.I.C.E. (Artificial Linguistic Internet Com...
# ELIZA                                               ELIZA is a computer program and an early examp...
# Wolfram Alpha                                       Wolfram Alpha (also styled WolframAlpha and Wo...
# Chinook                                             Chinook is a computer program that plays check...
# Blue Brain Project                                  The Blue Brain Project is an attempt to create...
# AIBO                                                AIBO (Artificial Intelligence Robot, homonymou...
# Braina                                              Braina is an intelligent personal assistant ap...
# CALO                                                CALO was an artificial intelligence project th...
# CHREST                                              CHREST (Chunk Hierarchy and REtrieval STructur...
# Cleverbot                                           Cleverbot is a web application that uses an ar...
# Cog                                                 Cog was a project at the Humanoid Robotics Gro...
# CLARION                                             Connectionist Learning with Adaptive Rule Indu...
# DUAL                                                DUAL is a general cognitive architecture integ...
# EPIC                                                EPIC (Executive-Process/Interactive Control) i...
# FORR                                                FORR (FOr the Right Reasons) is a cognitive ar...
# FreeHAL                                             FreeHAL is a distributed computing project to ...
# Google Brain                                        Google Brain is a deep learning research proje...
# Grok                                                Grok for IT Analytics enables insights into IT...
# Procedural Reasoning System                         In artificial intelligence, a procedural reaso...
# Microsoft Cortana                                   In computing, Cortana is an intelligent person...
# Jabberwacky                                         Jabberwacky is a chatterbot created by British...
# Open Mind Common Sense                              Open Mind Common Sense (OMCS) is an artificial...
# P.A.N.                                              P.A.N. (A.K.A.: Poetry Analyzer, Textual Analy...
# PreAct                                              PreAct is a cognitive engine technology that i...
# Synthetic Environment for Analysis and Simulations  Purdue University's Synthetic Environment for ...
# R-CAST                                              R-CAST is a group decision support system base...
# Siri                                                Siri /ˈsɪri/ is an application for Apple Inc.'...
# SYSTRAN                                             SYSTRAN, founded by Dr. Peter Toma in 1968, is...
# TD-Gammon                                           TD-Gammon was a computer backgammon program de...
# InfoTame                                            Text analysis search engine originally develop...
# IDA and LIDA                                        The LIDA (Learning Intelligent Distribution Ag...
# NuPIC                                               The Numenta Platform for Intelligent Computing...
#
#                                                                Written in  \
# Project
# Deep Blue                                                           C/C++
# Stockfish AI                                                        C/C++
# Google Now                                                          C/C++
# OpenCog                                             C/C++, Python, Scheme
# Apache Mahout                                                        Java
# CoJACK                                                               Java
# Neuroph                                                              Java
# RapidMiner                                                           Java
# Weka                                                                 Java
# Encog                                                   Java, .Net, C/C++
# Watson                                                Java, C/C++, Prolog
# Deeplearning4j                                                 Java, CUDA
# PARRY                                                                LISP
# 4CAPS                                                                LISP
# ACT-R                                                                LISP
# Copycat                                                              LISP
# Mycin                                                                LISP
# SNePS                                                                LISP
# Soar                                                                 LISP
# Cyc                                                            LISP, CycL
# SHRDLU                                                Micro Planner, LISP
# Eurisko                                                       RLL-1, LISP
# Artificial Linguistic Internet Computer Entity          SETL, Java, C/C++
# ELIZA                                                                SLIP
# Wolfram Alpha                                            Wolfram Language
# Chinook                                                               NaN
# Blue Brain Project                                                    NaN
# AIBO                                                                  NaN
# Braina                                                                NaN
# CALO                                                                  NaN
# CHREST                                                                NaN
# Cleverbot                                                             NaN
# Cog                                                                   NaN
# CLARION                                                               NaN
# DUAL                                                                  NaN
# EPIC                                                                  NaN
# FORR                                                                  NaN
# FreeHAL                                                               NaN
# Google Brain                                                          NaN
# Grok                                                                  NaN
# Procedural Reasoning System                                           NaN
# Microsoft Cortana                                                     NaN
# Jabberwacky                                                           NaN
# Open Mind Common Sense                                                NaN
# P.A.N.                                                                NaN
# PreAct                                                                NaN
# Synthetic Environment for Analysis and Simulations                    NaN
# R-CAST                                                                NaN
# Siri                                                                  NaN
# SYSTRAN                                                               NaN
# TD-Gammon                                                             NaN
# InfoTame                                                              NaN
# IDA and LIDA                                                          NaN
# NuPIC                                                                 NaN
#
#                                                                                        Wikipedia Page  \
# Project
# Deep Blue                                           http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Stockfish AI                                           http://en.wikipedia.org/wiki/Stockfish_(chess)
# Google Now                                                    http://en.wikipedia.org/wiki/Google_Now
# OpenCog                                                          http://en.wikipedia.org/wiki/OpenCog
# Apache Mahout                                              http://en.wikipedia.org/wiki/Apache_Mahout
# CoJACK                                              http://en.wikipedia.org/wiki/JACK_Intelligent_...
# Neuroph                                                          http://en.wikipedia.org/wiki/Neuroph
# RapidMiner                                                    http://en.wikipedia.org/wiki/RapidMiner
# Weka                                                http://en.wikipedia.org/wiki/Weka_(machine_lea...
# Encog                                                              http://en.wikipedia.org/wiki/Encog
# Watson                                                 http://en.wikipedia.org/wiki/Watson_(computer)
# Deeplearning4j                                            http://en.wikipedia.org/wiki/Deeplearning4j
# PARRY                                                              http://en.wikipedia.org/wiki/PARRY
# 4CAPS                                                              http://en.wikipedia.org/wiki/4CAPS
# ACT-R                                                              http://en.wikipedia.org/wiki/ACT-R
# Copycat                                               http://en.wikipedia.org/wiki/Copycat_(software)
# Mycin                                                              http://en.wikipedia.org/wiki/Mycin
# SNePS                                                              http://en.wikipedia.org/wiki/SNePS
# Soar                                                http://en.wikipedia.org/wiki/Soar_(cognitive_a...
# Cyc                                                                  http://en.wikipedia.org/wiki/Cyc
# SHRDLU                                                            http://en.wikipedia.org/wiki/SHRDLU
# Eurisko                                                          http://en.wikipedia.org/wiki/Eurisko
# Artificial Linguistic Internet Computer Entity      http://en.wikipedia.org/wiki/Artificial_Lingui...
# ELIZA                                                              http://en.wikipedia.org/wiki/ELIZA
# Wolfram Alpha                                              http://en.wikipedia.org/wiki/Wolfram_Alpha
# Chinook                                             http://en.wikipedia.org/wiki/Chinook_(draughts...
# Blue Brain Project                                    http://en.wikipedia.org/wiki/Blue_Brain_Project
# AIBO                                                                http://en.wikipedia.org/wiki/AIBO
# Braina                                                            http://en.wikipedia.org/wiki/Braina
# CALO                                                                http://en.wikipedia.org/wiki/CALO
# CHREST                                                            http://en.wikipedia.org/wiki/CHREST
# Cleverbot                                                      http://en.wikipedia.org/wiki/Cleverbot
# Cog                                                        http://en.wikipedia.org/wiki/Cog_(project)
# CLARION                                             http://en.wikipedia.org/wiki/CLARION_(cognitiv...
# DUAL                                                http://en.wikipedia.org/wiki/DUAL_(cognitive_a...
# EPIC                                                http://en.wikipedia.org/wiki/EPIC_(cognitive_a...
# FORR                                                                http://en.wikipedia.org/wiki/FORR
# FreeHAL                                                          http://en.wikipedia.org/wiki/FreeHAL
# Google Brain                                                http://en.wikipedia.org/wiki/Google_Brain
# Grok                                                      http://en.wikipedia.org/wiki/Grok_(company)
# Procedural Reasoning System                         http://en.wikipedia.org/wiki/Procedural_Reason...
# Microsoft Cortana                                      http://en.wikipedia.org/wiki/Microsoft_Cortana
# Jabberwacky                                                  http://en.wikipedia.org/wiki/Jabberwacky
# Open Mind Common Sense                              http://en.wikipedia.org/wiki/Open_Mind_Common_...
# P.A.N.                                                            http://en.wikipedia.org/wiki/P.A.N.
# PreAct                                                            http://en.wikipedia.org/wiki/PreAct
# Synthetic Environment for Analysis and Simulations  http://en.wikipedia.org/wiki/Synthetic_Environ...
# R-CAST                                                            http://en.wikipedia.org/wiki/R-CAST
# Siri                                                                http://en.wikipedia.org/wiki/Siri
# SYSTRAN                                                          http://en.wikipedia.org/wiki/SYSTRAN
# TD-Gammon                                                      http://en.wikipedia.org/wiki/TD-Gammon
# InfoTame                                                                                          NaN
# IDA and LIDA                                        http://en.wikipedia.org/wiki/LIDA_(cognitive_a...
# NuPIC                                               http://en.wikipedia.org/wiki/Numenta#The_NuPIC...
#
#                                                                               Homepage or Source Code
# Project
# Deep Blue                                           http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Stockfish AI                                                           http://www.stockfishchess.org/
# Google Now                                                             http://google.com/landing/now/
# OpenCog                                                                           http://opencog.org/
# Apache Mahout                                                               http://mahout.apache.org/
# CoJACK                                                http://www.agent-software.com.au/products/jack/
# Neuroph                                                               http://neuroph.sourceforge.net/
# RapidMiner                                                                    https://rapidminer.com/
# Weka                                                            http://www.cs.waikato.ac.nz/~ml/weka/
# Encog                                                             http://www.heatonresearch.com/encog
# Watson                                              http://www.ibm.com/smarterplanet/us/en/ibmwatson/
# Deeplearning4j                                                                     deeplearning4j.org
# PARRY                                               http://www.cs.cmu.edu/afs/cs/project/ai-reposi...
# 4CAPS                                                        http://www.ccbi.cmu.edu/4CAPS/index.html
# ACT-R                                                                       http://act-r.psy.cmu.edu/
# Copycat                                             http://web.cecs.pdx.edu/~mm/how-to-get-copycat...
# Mycin                                                                                             NaN
# SNePS                                                               http://www.cse.buffalo.edu/sneps/
# Soar                                                                      http://soar.eecs.umich.edu/
# Cyc                                                                               http://www.cyc.com/
# SHRDLU                                                      http://hci.stanford.edu/~winograd/shrdlu/
# Eurisko                                             http://citeseerx.ist.psu.edu/viewdoc/download?...
# Artificial Linguistic Internet Computer Entity      https://code.google.com/p/aiml-en-us-foundatio...
# ELIZA                                                         https://github.com/jeffshrager/elizagen
# Wolfram Alpha                                                            http://www.wolframalpha.com/
# Chinook                                                       http://webdocs.cs.ualberta.ca/~chinook/
# Blue Brain Project                                                          http://bluebrain.epfl.ch/
# AIBO                                                                      http://www.sony-aibo.co.uk/
# Braina                                                              http://www.brainasoft.com/braina/
# CALO                                                              https://pal.sri.com/Plone/framework
# CHREST                                                                            http://chrest.info/
# Cleverbot                                                                   http://www.cleverbot.com/
# Cog                                                 http://groups.csail.mit.edu/lbr/humanoid-robot...
# CLARION                                                  http://www.cogsci.rpi.edu/~rsun/clarion.html
# DUAL                                                                                              NaN
# EPIC                                                                                              NaN
# FORR                                                http://www.compsci.hunter.cuny.edu/~epstein/ht...
# FreeHAL                                                                     http://freehal.github.io/
# Google Brain                                                                                      NaN
# Grok                                                                         http://numenta.com/grok/
# Procedural Reasoning System                                               http://www.ai.sri.com/~prs/
# Microsoft Cortana                                   http://www.windowsphone.com/en-us/how-to/wp8/c...
# Jabberwacky                                                               http://www.jabberwacky.com/
# Open Mind Common Sense                                                                            NaN
# P.A.N.                                                                    http://pan.sourceforge.net/
# PreAct                                                                                            NaN
# Synthetic Environment for Analysis and Simulations  http://www.krannert.purdue.edu/centers/perc/ht...
# R-CAST                                                                                            NaN
# Siri                                                                   http://www.apple.com/ios/siri/
# SYSTRAN                                                                   http://www.systransoft.com/
# TD-Gammon                                                                                         NaN
# InfoTame                                                                     http://www.infotame.com/
# IDA and LIDA                                                                                      NaN
# NuPIC                                                                             http://numenta.org/

# %%
# Delete a row.
df.drop('Apache Mahout', axis=0)
# Out:
#                                                                                            Type  \
# Project
# Deep Blue                                                                  Specialized Projects
# Stockfish AI                                                               Specialized Projects
# Google Now                                                                 Specialized Projects
# OpenCog                                             Specialized Projects, Multipurpose Projects
# CoJACK                                                                     Specialized Projects
# Neuroph                                                                   Multipurpose Projects
# RapidMiner                                                                Multipurpose Projects
# Weka                                                                      Multipurpose Projects
# Encog                                                                     Multipurpose Projects
# Watson                                              Specialized Projects, Multipurpose Projects
# Deeplearning4j                                                            Multipurpose Projects
# PARRY                                                                      Specialized Projects
# 4CAPS                                                                      Specialized Projects
# ACT-R                                                                      Specialized Projects
# Copycat                                                                    Specialized Projects
# Mycin                                                                      Specialized Projects
# SNePS                                                                      Specialized Projects
# Soar                                                                       Specialized Projects
# Cyc                                                                        Specialized Projects
# SHRDLU                                                                     Specialized Projects
# Eurisko                                                                    Specialized Projects
# Artificial Linguistic Internet Computer Entity                             Specialized Projects
# ELIZA                                                                      Specialized Projects
# Wolfram Alpha                                                              Specialized Projects
# Chinook                                                                    Specialized Projects
# Blue Brain Project                                                         Specialized Projects
# AIBO                                                                       Specialized Projects
# Braina                                                                     Specialized Projects
# CALO                                                                       Specialized Projects
# CHREST                                                                     Specialized Projects
# Cleverbot                                                                  Specialized Projects
# Cog                                                                        Specialized Projects
# CLARION                                                                    Specialized Projects
# DUAL                                                                       Specialized Projects
# EPIC                                                                       Specialized Projects
# FORR                                                                       Specialized Projects
# FreeHAL                                                                    Specialized Projects
# Google Brain                                                               Specialized Projects
# Grok                                                                      Multipurpose Projects
# Procedural Reasoning System                                                Specialized Projects
# Microsoft Cortana                                                          Specialized Projects
# Jabberwacky                                                                Specialized Projects
# Open Mind Common Sense                                                     Specialized Projects
# P.A.N.                                                                     Specialized Projects
# PreAct                                                                     Specialized Projects
# Synthetic Environment for Analysis and Simulations                         Specialized Projects
# R-CAST                                                                     Specialized Projects
# Siri                                                                       Specialized Projects
# SYSTRAN                                                                    Specialized Projects
# TD-Gammon                                                                  Specialized Projects
# InfoTame                                                                   Specialized Projects
# IDA and LIDA                                                               Specialized Projects
# NuPIC                                                                      Specialized Projects
#
#                                                                                       Category  \
# Project
# Deep Blue                                                                                Games
# Stockfish AI                                                                             Games
# Google Now                                                             Knowledge and Reasoning
# OpenCog                                             Cognitive Architechture, Software Packages
# CoJACK                                                                 Cognitive Architechture
# Neuroph                                                                      Software Packages
# RapidMiner                                                                   Software Packages
# Weka                                                                            Cloud Services
# Encog                                                                        Software Packages
# Watson                                                 Knowledge and Reasoning, Cloud Services
# Deeplearning4j                                                               Software Packages
# PARRY                                                              Natural Language Processing
# 4CAPS                                                                  Cognitive Architechture
# ACT-R                                                                  Cognitive Architechture
# Copycat                                                                Cognitive Architechture
# Mycin                                                                  Knowledge and Reasoning
# SNePS                                                                  Knowledge and Reasoning
# Soar                                                                   Cognitive Architechture
# Cyc                                                                    Knowledge and Reasoning
# SHRDLU                                                             Natural Language Processing
# Eurisko                                                                Knowledge and Reasoning
# Artificial Linguistic Internet Computer Entity                     Natural Language Processing
# ELIZA                                                              Natural Language Processing
# Wolfram Alpha                                                          Knowledge and Reasoning
# Chinook                                                                                  Games
# Blue Brain Project                                                              Brain Inspired
# AIBO                                                                  Motion and Manipulations
# Braina                                                                 Knowledge and Reasoning
# CALO                                                                   Cognitive Architechture
# CHREST                                                                 Cognitive Architechture
# Cleverbot                                                          Natural Language Processing
# Cog                                                                   Motion and Manipulations
# CLARION                                                                Cognitive Architechture
# DUAL                                                                   Cognitive Architechture
# EPIC                                                                   Cognitive Architechture
# FORR                                                                   Cognitive Architechture
# FreeHAL                                                                                  Games
# Google Brain                                                                    Brain Inspired
# Grok                                                                            Cloud Services
# Procedural Reasoning System                                            Cognitive Architechture
# Microsoft Cortana                                                      Knowledge and Reasoning
# Jabberwacky                                                        Natural Language Processing
# Open Mind Common Sense                                                 Knowledge and Reasoning
# P.A.N.                                                                 Knowledge and Reasoning
# PreAct                                                                 Cognitive Architechture
# Synthetic Environment for Analysis and Simulations                                       Other
# R-CAST                                                                 Cognitive Architechture
# Siri                                                                   Knowledge and Reasoning
# SYSTRAN                                                            Natural Language Processing
# TD-Gammon                                                                                Games
# InfoTame                                                           Natural Language Processing
# IDA and LIDA                                                           Cognitive Architechture
# NuPIC                                                                           Brain Inspired
#
#                                                                                  Insitution / Company  \
# Project
# Deep Blue                                                             IBM, Carnegie Mellon University
# Stockfish AI                                                                                      NaN
# Google Now                                                                                     Google
# OpenCog                                                                            OpenCog Foundation
# CoJACK                                                                        Agent Oriented Software
# Neuroph                                                                        University of Belgrade
# RapidMiner                                                          Dortmund University of Technology
# Weka                                                                            University of Waikato
# Encog                                                                                 Heaton Research
# Watson                                                                                            IBM
# Deeplearning4j                                                                                    NaN
# PARRY                                                                             Stanford University
# 4CAPS                                                                      Carnegie Mellon University
# ACT-R                                                                      Carnegie Mellon University
# Copycat                                                                            Indiana University
# Mycin                                                                             Stanford University
# SNePS                                                         State University of New York at Buffalo
# Soar                                                Carnegie Mellon University, University of Mich...
# Cyc                                                 Microelectronics and Computer Technology Corpo...
# SHRDLU                                                                                            MIT
# Eurisko                                              Carnegie Mellon University,  Stanford University
# Artificial Linguistic Internet Computer Entity                                                    NaN
# ELIZA                                                                                             MIT
# Wolfram Alpha                                                                        Wolfram Research
# Chinook                                                                         University of Alberta
# Blue Brain Project                                           École Polytechnique Fédérale de Lausanne
# AIBO                                                                                             Sony
# Braina                                                                                     Brainasoft
# CALO                                                                                SRI International
# CHREST                                                 Brunel University, University of Hertfordshire
# Cleverbot                                                                                         NaN
# Cog                                                                                               MIT
# CLARION                                             Rensselaer Polytechnic Institute, University o...
# DUAL                                                                         New Bulgarian University
# EPIC                                                                           University of Michigan
# FORR                                                                  The City University of New York
# FreeHAL                                                                                           NaN
# Google Brain                                                                                   Google
# Grok                                                                                          Numenta
# Procedural Reasoning System                                                         SRI International
# Microsoft Cortana                                                                           Microsoft
# Jabberwacky                                                                                       NaN
# Open Mind Common Sense                                                                            MIT
# P.A.N.                                                                                            NaN
# PreAct                                                                   Applied Systems Intelligence
# Synthetic Environment for Analysis and Simulations                                  Purdue University
# R-CAST                                                                  Pennsylvania State University
# Siri                                                                                        Siri Inc.
# SYSTRAN                                                                                       SYSTRAN
# TD-Gammon                                                                                         IBM
# InfoTame                                                                                          KGB
# IDA and LIDA                                                                    University of Memphis
# NuPIC                                                                                         Numenta
#
#                                                                       Developer / Author / Group Lead  \
# Project
# Deep Blue                                           Feng-hsiung Hsu, Thomas Anantharaman, Murray C...
# Stockfish AI                                               Tord Romstad, Marco Costalba, Joona Kiiski
# Google Now                                                                                        NaN
# OpenCog                                                                                  Ben Goertzel
# CoJACK                                                                                            NaN
# Neuroph                                                                                           NaN
# RapidMiner                                              Ralf Klinkenberg, Ingo Mierswa, Simon Fischer
# Weka                                                                                              NaN
# Encog                                                                                     Jeff Heaton
# Watson                                                                                            NaN
# Deeplearning4j                                                                            Adam Gibson
# PARRY                                                                                   Kenneth Colby
# 4CAPS                                                                   Marcel A. Just, Sashank Varma
# ACT-R                                                                            John Robert Anderson
# Copycat                                                          Douglas Hofstadter, Melanie Mitchell
# Mycin                                               Edward Shortliffe, Bruce Buchanan, Stanley N. ...
# SNePS                                                                               Stuart C. Shapiro
# Soar                                                        John Laird, Allen Newell, Paul Rosenbloom
# Cyc                                                                                     Douglas Lenat
# SHRDLU                                                                                 Terry Winograd
# Eurisko                                                                                 Douglas Lenat
# Artificial Linguistic Internet Computer Entity                                        Richard Wallace
# ELIZA                                                                               Joseph Weizenbaum
# Wolfram Alpha                                                                                     NaN
# Chinook                                             Jonathan Schaeffer, Rob Lake, Paul Lu, Martin ...
# Blue Brain Project                                          Henry Markram, Felix Schürmann, Sean Hill
# AIBO                                                                                    Toshitada Doi
# Braina                                                                                            NaN
# CALO                                                                                              NaN
# CHREST                                                                   Fernand Gobet, Peter C. Lane
# Cleverbot                                                                             Rollo Carpenter
# Cog                                                                                               NaN
# CLARION                                                                                       Ron Sun
# DUAL                                                                                   Boicho Kokinov
# EPIC                                                                  David E. Kieras, David E. Meyer
# FORR                                                                                              NaN
# FreeHAL                                                                                 Tobias Schulz
# Google Brain                                                                    Andrew Ng,  Jeff Dean
# Grok                                                                                              NaN
# Procedural Reasoning System                                                                       NaN
# Microsoft Cortana                                                                                 NaN
# Jabberwacky                                                                           Rollo Carpenter
# Open Mind Common Sense                                    Marvin Minsky, Push Singh, Catherine Havasi
# P.A.N.                                                                           David Benjamin Bowes
# PreAct                                                                                    Norm Geddes
# Synthetic Environment for Analysis and Simulations                                 Alok R. Chaturvedi
# R-CAST                                                                                       John Yen
# Siri                                                                                              NaN
# SYSTRAN                                                                                    Peter Toma
# TD-Gammon                                                                              Gerald Tesauro
# InfoTame                                                                                          NaN
# IDA and LIDA                                                                            Stan Franklin
# NuPIC                                                                                             NaN
#
#                                                           Location   Year  \
# Project
# Deep Blue                                            United States   1985
# Stockfish AI                                         Norway, Italy   2004
# Google Now                                           United States   2012
# OpenCog                                              United States   2008
# CoJACK                                                   Australia   1997
# Neuroph                                                     Serbia   2008
# RapidMiner                                           United States   2001
# Weka                                                   New Zealand   1993
# Encog                                                United States   2008
# Watson                                               United States   2005
# Deeplearning4j                                       United States    NaN
# PARRY                                                United States   1972
# 4CAPS                                                United States   2006
# ACT-R                                                United States   1993
# Copycat                                              United States   1988
# Mycin                                                United States  1970s
# SNePS                                                United States    NaN
# Soar                                                 United States   1983
# Cyc                                                  United States   1984
# SHRDLU                                               United States   1968
# Eurisko                                              United States   1976
# Artificial Linguistic Internet Computer Entity       United States   1995
# ELIZA                                                United States   1964
# Wolfram Alpha                                        United States   2009
# Chinook                                                     Canada   1989
# Blue Brain Project                                     Switzerland   2005
# AIBO                                                         Japan   1998
# Braina                                                       India    NaN
# CALO                                                 United States   2003
# CHREST                                              United Kingdom   1992
# Cleverbot                                            United States   1997
# Cog                                                  United States    NaN
# CLARION                                              United States    NaN
# DUAL                                                      Bulgaria    NaN
# EPIC                                                 United States    NaN
# FORR                                                 United States    NaN
# FreeHAL                                                    Germany   2006
# Google Brain                                         United States   2001
# Grok                                                 United States    NaN
# Procedural Reasoning System                          United States    NaN
# Microsoft Cortana                                    United States   2014
# Jabberwacky                                         United Kingdom   1988
# Open Mind Common Sense                               United States   1999
# P.A.N.                                                         NaN   2005
# PreAct                                               United States    NaN
# Synthetic Environment for Analysis and Simulations   United States   2004
# R-CAST                                               United States    NaN
# Siri                                                 United States   2010
# SYSTRAN                                              United States   1968
# TD-Gammon                                            United States   1992
# InfoTame                                                    Russia    NaN
# IDA and LIDA                                         United States    NaN
# NuPIC                                                United States   2007
#
#                                                                                           Description  \
# Project
# Deep Blue                                           Deep Blue was a chess-playing computer develop...
# Stockfish AI                                        Stockfish is a strong open source UCI chess en...
# Google Now                                          Google Now is an intelligent personal assistan...
# OpenCog                                             OpenCog is a project that aims to build an ope...
# CoJACK                                              Jack Intelligent Agent JACK is a framework in ...
# Neuroph                                             Neuroph is an object-oriented neural network f...
# RapidMiner                                          RapidMiner is a software platform developed by...
# Weka                                                Weka (Waikato Environment for Knowledge Analys...
# Encog                                               Encog is a machine learning framework availabl...
# Watson                                              Watson is an artificially intelligent computer...
# Deeplearning4j                                      Deeplearning4j is an open source deep learning...
# PARRY                                               PARRY was an early example of a chatterbot, im...
# 4CAPS                                               4CAPS (Cortical Capacity-Constrained Concurren...
# ACT-R                                               ACT-R (pronounced act-ARE; short for "Adaptive...
# Copycat                                             Copycat is a model of analogy making and human...
# Mycin                                               MYCIN was an early expert system that used art...
# SNePS                                               SNePS is a knowledge representation, reasoning...
# Soar                                                Soar is a cognitive architecture, created by J...
# Cyc                                                 Cyc is an artificial intelligence project that...
# SHRDLU                                              SHRDLU was an early natural language understan...
# Eurisko                                             Eurisko (Gr., I discover) is a program written...
# Artificial Linguistic Internet Computer Entity      A.L.I.C.E. (Artificial Linguistic Internet Com...
# ELIZA                                               ELIZA is a computer program and an early examp...
# Wolfram Alpha                                       Wolfram Alpha (also styled WolframAlpha and Wo...
# Chinook                                             Chinook is a computer program that plays check...
# Blue Brain Project                                  The Blue Brain Project is an attempt to create...
# AIBO                                                AIBO (Artificial Intelligence Robot, homonymou...
# Braina                                              Braina is an intelligent personal assistant ap...
# CALO                                                CALO was an artificial intelligence project th...
# CHREST                                              CHREST (Chunk Hierarchy and REtrieval STructur...
# Cleverbot                                           Cleverbot is a web application that uses an ar...
# Cog                                                 Cog was a project at the Humanoid Robotics Gro...
# CLARION                                             Connectionist Learning with Adaptive Rule Indu...
# DUAL                                                DUAL is a general cognitive architecture integ...
# EPIC                                                EPIC (Executive-Process/Interactive Control) i...
# FORR                                                FORR (FOr the Right Reasons) is a cognitive ar...
# FreeHAL                                             FreeHAL is a distributed computing project to ...
# Google Brain                                        Google Brain is a deep learning research proje...
# Grok                                                Grok for IT Analytics enables insights into IT...
# Procedural Reasoning System                         In artificial intelligence, a procedural reaso...
# Microsoft Cortana                                   In computing, Cortana is an intelligent person...
# Jabberwacky                                         Jabberwacky is a chatterbot created by British...
# Open Mind Common Sense                              Open Mind Common Sense (OMCS) is an artificial...
# P.A.N.                                              P.A.N. (A.K.A.: Poetry Analyzer, Textual Analy...
# PreAct                                              PreAct is a cognitive engine technology that i...
# Synthetic Environment for Analysis and Simulations  Purdue University's Synthetic Environment for ...
# R-CAST                                              R-CAST is a group decision support system base...
# Siri                                                Siri /ˈsɪri/ is an application for Apple Inc.'...
# SYSTRAN                                             SYSTRAN, founded by Dr. Peter Toma in 1968, is...
# TD-Gammon                                           TD-Gammon was a computer backgammon program de...
# InfoTame                                            Text analysis search engine originally develop...
# IDA and LIDA                                        The LIDA (Learning Intelligent Distribution Ag...
# NuPIC                                               The Numenta Platform for Intelligent Computing...
#
#                                                                Written in  \
# Project
# Deep Blue                                                           C/C++
# Stockfish AI                                                        C/C++
# Google Now                                                          C/C++
# OpenCog                                             C/C++, Python, Scheme
# CoJACK                                                               Java
# Neuroph                                                              Java
# RapidMiner                                                           Java
# Weka                                                                 Java
# Encog                                                   Java, .Net, C/C++
# Watson                                                Java, C/C++, Prolog
# Deeplearning4j                                                 Java, CUDA
# PARRY                                                                LISP
# 4CAPS                                                                LISP
# ACT-R                                                                LISP
# Copycat                                                              LISP
# Mycin                                                                LISP
# SNePS                                                                LISP
# Soar                                                                 LISP
# Cyc                                                            LISP, CycL
# SHRDLU                                                Micro Planner, LISP
# Eurisko                                                       RLL-1, LISP
# Artificial Linguistic Internet Computer Entity          SETL, Java, C/C++
# ELIZA                                                                SLIP
# Wolfram Alpha                                            Wolfram Language
# Chinook                                                               NaN
# Blue Brain Project                                                    NaN
# AIBO                                                                  NaN
# Braina                                                                NaN
# CALO                                                                  NaN
# CHREST                                                                NaN
# Cleverbot                                                             NaN
# Cog                                                                   NaN
# CLARION                                                               NaN
# DUAL                                                                  NaN
# EPIC                                                                  NaN
# FORR                                                                  NaN
# FreeHAL                                                               NaN
# Google Brain                                                          NaN
# Grok                                                                  NaN
# Procedural Reasoning System                                           NaN
# Microsoft Cortana                                                     NaN
# Jabberwacky                                                           NaN
# Open Mind Common Sense                                                NaN
# P.A.N.                                                                NaN
# PreAct                                                                NaN
# Synthetic Environment for Analysis and Simulations                    NaN
# R-CAST                                                                NaN
# Siri                                                                  NaN
# SYSTRAN                                                               NaN
# TD-Gammon                                                             NaN
# InfoTame                                                              NaN
# IDA and LIDA                                                          NaN
# NuPIC                                                                 NaN
#
#                                                                                                 Image  \
# Project
# Deep Blue                                           http://upload.wikimedia.org/wikipedia/commons/...
# Stockfish AI                                        http://upload.wikimedia.org/wikipedia/en/thumb...
# Google Now                                          http://upload.wikimedia.org/wikipedia/en/thumb...
# OpenCog                                             http://upload.wikimedia.org/wikipedia/en/thumb...
# CoJACK                                                                                            NaN
# Neuroph                                                                                           NaN
# RapidMiner                                          http://upload.wikimedia.org/wikipedia/commons/...
# Weka                                                http://upload.wikimedia.org/wikipedia/commons/...
# Encog                                               http://upload.wikimedia.org/wikipedia/en/5/5c/...
# Watson                                              http://upload.wikimedia.org/wikipedia/commons/...
# Deeplearning4j                                                                                    NaN
# PARRY                                                                                             NaN
# 4CAPS                                                                                             NaN
# ACT-R                                                                                             NaN
# Copycat                                                                                           NaN
# Mycin                                                                                             NaN
# SNePS                                                                                             NaN
# Soar                                                                                              NaN
# Cyc                                                                                               NaN
# SHRDLU                                                                                            NaN
# Eurisko                                             http://wiki.lesswrong.com/mediawiki/images/5/5...
# Artificial Linguistic Internet Computer Entity                                                    NaN
# ELIZA                                               http://upload.wikimedia.org/wikipedia/commons/...
# Wolfram Alpha                                       http://upload.wikimedia.org/wikipedia/en/thumb...
# Chinook                                                                                           NaN
# Blue Brain Project                                                                                NaN
# AIBO                                                http://upload.wikimedia.org/wikipedia/commons/...
# Braina                                                                                            NaN
# CALO                                                                                              NaN
# CHREST                                                                                            NaN
# Cleverbot                                                                                         NaN
# Cog                                                 http://www.ai.mit.edu/projects/cog/Pictures/he...
# CLARION                                                                                           NaN
# DUAL                                                                                              NaN
# EPIC                                                                                              NaN
# FORR                                                                                              NaN
# FreeHAL                                                                                           NaN
# Google Brain                                                                                      NaN
# Grok                                                                                              NaN
# Procedural Reasoning System                                                                       NaN
# Microsoft Cortana                                   http://upload.wikimedia.org/wikipedia/en/thumb...
# Jabberwacky                                                                                       NaN
# Open Mind Common Sense                                                                            NaN
# P.A.N.                                                                                            NaN
# PreAct                                                                                            NaN
# Synthetic Environment for Analysis and Simulations                                                NaN
# R-CAST                                                                                            NaN
# Siri                                                http://upload.wikimedia.org/wikipedia/en/thumb...
# SYSTRAN                                                                                           NaN
# TD-Gammon                                           http://upload.wikimedia.org/wikipedia/commons/...
# InfoTame                                                                                          NaN
# IDA and LIDA                                                                                      NaN
# NuPIC                                                                                             NaN
#
#                                                                                        Wikipedia Page  \
# Project
# Deep Blue                                           http://en.wikipedia.org/wiki/Deep_Blue_(chess_...
# Stockfish AI                                           http://en.wikipedia.org/wiki/Stockfish_(chess)
# Google Now                                                    http://en.wikipedia.org/wiki/Google_Now
# OpenCog                                                          http://en.wikipedia.org/wiki/OpenCog
# CoJACK                                              http://en.wikipedia.org/wiki/JACK_Intelligent_...
# Neuroph                                                          http://en.wikipedia.org/wiki/Neuroph
# RapidMiner                                                    http://en.wikipedia.org/wiki/RapidMiner
# Weka                                                http://en.wikipedia.org/wiki/Weka_(machine_lea...
# Encog                                                              http://en.wikipedia.org/wiki/Encog
# Watson                                                 http://en.wikipedia.org/wiki/Watson_(computer)
# Deeplearning4j                                            http://en.wikipedia.org/wiki/Deeplearning4j
# PARRY                                                              http://en.wikipedia.org/wiki/PARRY
# 4CAPS                                                              http://en.wikipedia.org/wiki/4CAPS
# ACT-R                                                              http://en.wikipedia.org/wiki/ACT-R
# Copycat                                               http://en.wikipedia.org/wiki/Copycat_(software)
# Mycin                                                              http://en.wikipedia.org/wiki/Mycin
# SNePS                                                              http://en.wikipedia.org/wiki/SNePS
# Soar                                                http://en.wikipedia.org/wiki/Soar_(cognitive_a...
# Cyc                                                                  http://en.wikipedia.org/wiki/Cyc
# SHRDLU                                                            http://en.wikipedia.org/wiki/SHRDLU
# Eurisko                                                          http://en.wikipedia.org/wiki/Eurisko
# Artificial Linguistic Internet Computer Entity      http://en.wikipedia.org/wiki/Artificial_Lingui...
# ELIZA                                                              http://en.wikipedia.org/wiki/ELIZA
# Wolfram Alpha                                              http://en.wikipedia.org/wiki/Wolfram_Alpha
# Chinook                                             http://en.wikipedia.org/wiki/Chinook_(draughts...
# Blue Brain Project                                    http://en.wikipedia.org/wiki/Blue_Brain_Project
# AIBO                                                                http://en.wikipedia.org/wiki/AIBO
# Braina                                                            http://en.wikipedia.org/wiki/Braina
# CALO                                                                http://en.wikipedia.org/wiki/CALO
# CHREST                                                            http://en.wikipedia.org/wiki/CHREST
# Cleverbot                                                      http://en.wikipedia.org/wiki/Cleverbot
# Cog                                                        http://en.wikipedia.org/wiki/Cog_(project)
# CLARION                                             http://en.wikipedia.org/wiki/CLARION_(cognitiv...
# DUAL                                                http://en.wikipedia.org/wiki/DUAL_(cognitive_a...
# EPIC                                                http://en.wikipedia.org/wiki/EPIC_(cognitive_a...
# FORR                                                                http://en.wikipedia.org/wiki/FORR
# FreeHAL                                                          http://en.wikipedia.org/wiki/FreeHAL
# Google Brain                                                http://en.wikipedia.org/wiki/Google_Brain
# Grok                                                      http://en.wikipedia.org/wiki/Grok_(company)
# Procedural Reasoning System                         http://en.wikipedia.org/wiki/Procedural_Reason...
# Microsoft Cortana                                      http://en.wikipedia.org/wiki/Microsoft_Cortana
# Jabberwacky                                                  http://en.wikipedia.org/wiki/Jabberwacky
# Open Mind Common Sense                              http://en.wikipedia.org/wiki/Open_Mind_Common_...
# P.A.N.                                                            http://en.wikipedia.org/wiki/P.A.N.
# PreAct                                                            http://en.wikipedia.org/wiki/PreAct
# Synthetic Environment for Analysis and Simulations  http://en.wikipedia.org/wiki/Synthetic_Environ...
# R-CAST                                                            http://en.wikipedia.org/wiki/R-CAST
# Siri                                                                http://en.wikipedia.org/wiki/Siri
# SYSTRAN                                                          http://en.wikipedia.org/wiki/SYSTRAN
# TD-Gammon                                                      http://en.wikipedia.org/wiki/TD-Gammon
# InfoTame                                                                                          NaN
# IDA and LIDA                                        http://en.wikipedia.org/wiki/LIDA_(cognitive_a...
# NuPIC                                               http://en.wikipedia.org/wiki/Numenta#The_NuPIC...
#
#                                                                               Homepage or Source Code
# Project
# Deep Blue                                           http://www-03.ibm.com/ibm/history/ibm100/us/en...
# Stockfish AI                                                           http://www.stockfishchess.org/
# Google Now                                                             http://google.com/landing/now/
# OpenCog                                                                           http://opencog.org/
# CoJACK                                                http://www.agent-software.com.au/products/jack/
# Neuroph                                                               http://neuroph.sourceforge.net/
# RapidMiner                                                                    https://rapidminer.com/
# Weka                                                            http://www.cs.waikato.ac.nz/~ml/weka/
# Encog                                                             http://www.heatonresearch.com/encog
# Watson                                              http://www.ibm.com/smarterplanet/us/en/ibmwatson/
# Deeplearning4j                                                                     deeplearning4j.org
# PARRY                                               http://www.cs.cmu.edu/afs/cs/project/ai-reposi...
# 4CAPS                                                        http://www.ccbi.cmu.edu/4CAPS/index.html
# ACT-R                                                                       http://act-r.psy.cmu.edu/
# Copycat                                             http://web.cecs.pdx.edu/~mm/how-to-get-copycat...
# Mycin                                                                                             NaN
# SNePS                                                               http://www.cse.buffalo.edu/sneps/
# Soar                                                                      http://soar.eecs.umich.edu/
# Cyc                                                                               http://www.cyc.com/
# SHRDLU                                                      http://hci.stanford.edu/~winograd/shrdlu/
# Eurisko                                             http://citeseerx.ist.psu.edu/viewdoc/download?...
# Artificial Linguistic Internet Computer Entity      https://code.google.com/p/aiml-en-us-foundatio...
# ELIZA                                                         https://github.com/jeffshrager/elizagen
# Wolfram Alpha                                                            http://www.wolframalpha.com/
# Chinook                                                       http://webdocs.cs.ualberta.ca/~chinook/
# Blue Brain Project                                                          http://bluebrain.epfl.ch/
# AIBO                                                                      http://www.sony-aibo.co.uk/
# Braina                                                              http://www.brainasoft.com/braina/
# CALO                                                              https://pal.sri.com/Plone/framework
# CHREST                                                                            http://chrest.info/
# Cleverbot                                                                   http://www.cleverbot.com/
# Cog                                                 http://groups.csail.mit.edu/lbr/humanoid-robot...
# CLARION                                                  http://www.cogsci.rpi.edu/~rsun/clarion.html
# DUAL                                                                                              NaN
# EPIC                                                                                              NaN
# FORR                                                http://www.compsci.hunter.cuny.edu/~epstein/ht...
# FreeHAL                                                                     http://freehal.github.io/
# Google Brain                                                                                      NaN
# Grok                                                                         http://numenta.com/grok/
# Procedural Reasoning System                                               http://www.ai.sri.com/~prs/
# Microsoft Cortana                                   http://www.windowsphone.com/en-us/how-to/wp8/c...
# Jabberwacky                                                               http://www.jabberwacky.com/
# Open Mind Common Sense                                                                            NaN
# P.A.N.                                                                    http://pan.sourceforge.net/
# PreAct                                                                                            NaN
# Synthetic Environment for Analysis and Simulations  http://www.krannert.purdue.edu/centers/perc/ht...
# R-CAST                                                                                            NaN
# Siri                                                                   http://www.apple.com/ios/siri/
# SYSTRAN                                                                   http://www.systransoft.com/
# TD-Gammon                                                                                         NaN
# InfoTame                                                                     http://www.infotame.com/
# IDA and LIDA                                                                                      NaN
# NuPIC                                                                             http://numenta.org/

# %%
# Delete all rows that contain the value 'LISP' in column 'Written in'.
